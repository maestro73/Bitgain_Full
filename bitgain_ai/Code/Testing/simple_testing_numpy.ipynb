# %%
# Machine learning classification libraries
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import scorer
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler
 
# For data manipulation
import pandas as pd
import numpy as np
 
# To plot
import matplotlib.pyplot as plt
import seaborn
 
# To fetch data
import pandas_datareader.data as web
import stockstats as ss

import time

import bs4 as bs
import pickle
import requests
import winsound

def save_sp500_tickers():
    resp = requests.get('http://en.wikipedia.org/wiki/List_of_S%26P_500_companies')
    soup = bs.BeautifulSoup(resp.text, 'lxml')
    table = soup.find('table', {'class': 'wikitable sortable'})
    tickers = []
    for row in table.findAll('tr')[1:]:
        ticker = row.findAll('td')[1].text #change to 0 to get company names instead of tickers
        tickers.append(ticker)
        
    #with open("sp500tickers.pickle","wb") as f:
        #pickle.dump(tickers,f)
        
    return sorted(tickers)

sp500 = save_sp500_tickers()

# %%
import alpaca_trade_api as tradeapi
import time
import datetime
from datetime import timedelta
from pytz import timezone
import pandas as pd
import stockstats as ss
tz = timezone('EST')

api = tradeapi.REST('PKQ696NV2EWC8UJT6MWW',
                    'X2XXULiG1Iq/zhxIWa2TRp0j/Ut5ZBjdlwK4fW13',
                    'https://paper-api.alpaca.markets')

ticker = 'XOM'
for position in api.list_positions():
    if position.symbol == ticker:
        print(position.qty)

api.list_positions()

#Df = api.polygon.historic_agg('min', 'AAPL').df
#print(type(Df))
# Out:
# 5
# [Position({   'asset_class': 'us_equity',
#      'asset_id': '092efc51-b66b-4355-8132-d9c3796b9a76',
#      'avg_entry_price': '79.59',
#      'change_today': '0.0045354253493503',
#      'cost_basis': '397.95',
#      'current_price': '81.95',
#      'exchange': 'NYSE',
#      'lastday_price': '81.58',
#      'market_value': '409.75',
#      'qty': '5',
#      'side': 'long',
#      'symbol': 'XOM',
#      'unrealized_intraday_pl': '1.85',
#      'unrealized_intraday_plpc': '0.0045354253493503',
#      'unrealized_pl': '11.8',
#      'unrealized_plpc': '0.0296519663274281'}),
#  Position({   'asset_class': 'us_equity',
#      'asset_id': '346931c8-f921-4834-87e6-a0505d5d0b5d',
#      'avg_entry_price': '122.1',
#      'change_today': '0.0045599635202918',
#      'cost_basis': '610.5',
#      'current_price': '132.18',
#      'exchange': 'NASDAQ',
#      'lastday_price': '131.58',
#      'market_value': '660.9',
#      'qty': '5',
#      'side': 'long',
#      'symbol': 'XLNX',
#      'unrealized_intraday_pl': '3',
#      'unrealized_intraday_plpc': '0.0045599635202918',
#      'unrealized_pl': '50.4',
#      'unrealized_plpc': '0.0825552825552826'}),
#  Position({   'asset_class': 'us_equity',
#      'asset_id': '0e0c0862-4cca-4f81-b954-12b51e86090b',
#      'avg_entry_price': '18.12',
#      'change_today': '-0.0149716055756324',
#      'cost_basis': '90.6',
#      'current_price': '19.08',
#      'exchange': 'NYSE',
#      'lastday_price': '19.37',
#      'market_value': '95.4',
#      'qty': '5',
#      'side': 'long',
#      'symbol': 'WU',
#      'unrealized_intraday_pl': '-1.45',
#      'unrealized_intraday_plpc': '-0.0149716055756324',
#      'unrealized_pl': '4.8',
#      'unrealized_plpc': '0.0529801324503311'}),
#  Position({   'asset_class': 'us_equity',
#      'asset_id': '3f3e0ff9-599f-4fec-8842-6bc53f5129a1',
#      'avg_entry_price': '97.73',
#      'change_today': '0.0098383696416022',
#      'cost_basis': '488.65',
#      'current_price': '100.59',
#      'exchange': 'NYSE',
#      'lastday_price': '99.61',
#      'market_value': '502.95',
#      'qty': '5',
#      'side': 'long',
#      'symbol': 'WMT',
#      'unrealized_intraday_pl': '4.9',
#      'unrealized_intraday_plpc': '0.0098383696416022',
#      'unrealized_pl': '14.3',
#      'unrealized_plpc': '0.0292642996009414'}),
#  Position({   'asset_class': 'us_equity',
#      'asset_id': 'b60af993-7490-471e-9926-1cbedb46fcef',
#      'avg_entry_price': '27.16',
#      'change_today': '0.0003489183531054',
#      'cost_basis': '135.8',
#      'current_price': '28.67',
#      'exchange': 'NYSE',
#      'lastday_price': '28.66',
#      'market_value': '143.35',
#      'qty': '5',
#      'side': 'long',
#      'symbol': 'WMB',
#      'unrealized_intraday_pl': '0.05',
#      'unrealized_intraday_plpc': '0.0003489183531054',
#      'unrealized_pl': '7.55',
#      'unrealized_plpc': '0.0555964653902798'}),
#  Position({   'asset_class': 'us_equity',
#      'asset_id': '15110ac1-3d55-4832-bb54-f59ed4abeed1',
#      'avg_entry_price': '101.68',
#      'change_today': '-0.025162731953755',
#      'cost_basis': '508.4',
#      'current_price': '100.34',
#      'exchange': 'NYSE',
#      'lastday_price': '102.93',
#      'market_value': '501.7',
#      'qty': '5',
#      'side': 'long',
#      'symbol': 'WM',
#      'unrealized_intraday_pl': '-12.95',
#      'unrealized_intraday_plpc': '-0.025162731953755',
#      'unrealized_pl': '-6.7',
#      'unrealized_plpc': '-0.0131785995279308'}),
#  Position({   'asset_class': 'us_equity',
#      'asset_id': '70cb03f3-2184-4a3a-b04c-ad5ff9524612',
#      'avg_entry_price': '52.4',
#      'change_today': '-0.003353057199211',
#      'cost_basis': '262',
#      'current_price': '50.53',
#      'exchange': 'NASDAQ',
#      'lastday_price': '50.7',
#      'market_value': '252.65',
#      'qty': '5',
#      'side': 'long',
#      'symbol': 'WDC',
#      'unrealized_intraday_pl': '-0.85',
#      'unrealized_intraday_plpc': '-0.003353057199211',
#      'unrealized_pl': '-9.35',
#      'unrealized_plpc': '-0.0356870229007634'}),
#  Position({   'asset_class': 'us_equity',
#      'asset_id': 'c5bbc0b0-e2ce-40cd-9974-a4d2ffd201a9',
#      'avg_entry_price': '55.1',
#      'change_today': '-0.0194459732159237',
#      'cost_basis': '275.5',
#      'current_price': '53.45',
#      'exchange': 'NASDAQ',
#      'lastday_price': '54.51',
#      'market_value': '267.25',
#      'qty': '5',
#      'side': 'long',
#      'symbol': 'WBA',
#      'unrealized_intraday_pl': '-5.3',
#      'unrealized_intraday_plpc': '-0.0194459732159237',
#      'unrealized_pl': '-8.25',
#      'unrealized_plpc': '-0.02994555353902'}),
#  Position({   'asset_class': 'us_equity',
#      'asset_id': 'a760766c-8c49-4886-85af-990e47f9d78a',
#      'avg_entry_price': '62.24',
#      'change_today': '-0.0126177926848746',
#      'cost_basis': '311.2',
#      'current_price': '61.82',
#      'exchange': 'NYSE',
#      'lastday_price': '62.61',
#      'market_value': '309.1',
#      'qty': '5',
#      'side': 'long',
#      'symbol': 'VTR',
#      'unrealized_intraday_pl': '-3.95',
#      'unrealized_intraday_plpc': '-0.0126177926848746',
#      'unrealized_pl': '-2.1',
#      'unrealized_plpc': '-0.0067480719794344'}),
#  Position({   'asset_class': 'us_equity',
#      'asset_id': '74dc527d-cc0f-4fb5-b672-db5e71197434',
#      'avg_entry_price': '85.98',
#      'change_today': '-0.0019022043191227',
#      'cost_basis': '429.9',
#      'current_price': '89.2',
#      'exchange': 'NYSE',
#      'lastday_price': '89.37',
#      'market_value': '446',
#      'qty': '5',
#      'side': 'long',
#      'symbol': 'VFC',
#      'unrealized_intraday_pl': '-0.85',
#      'unrealized_intraday_plpc': '-0.0019022043191227',
#      'unrealized_pl': '16.1',
#      'unrealized_plpc': '0.0374505698999767'}),
#  Position({   'asset_class': 'us_equity',
#      'asset_id': '4f5baf1e-0e9b-4d85-b88a-d874dc4a3c42',
#      'avg_entry_price': '147.81',
#      'change_today': '-0.0067422810333963',
#      'cost_basis': '739.05',
#      'current_price': '157.63',
#      'exchange': 'NYSE',
#      'lastday_price': '158.7',
#      'market_value': '788.15',
#      'qty': '5',
#      'side': 'long',
#      'symbol': 'V',
#      'unrealized_intraday_pl': '-5.35',
#      'unrealized_intraday_plpc': '-0.0067422810333963',
#      'unrealized_pl': '49.1',
#      'unrealized_plpc': '0.0664366416345308'}),
#  Position({   'asset_class': 'us_equity',
#      'asset_id': '5553e8c9-004d-479d-a18c-83a42a87ed10',
#      'avg_entry_price': '51.36',
#      'change_today': '0.0046653144016227',
#      'cost_basis': '256.8',
#      'current_price': '49.53',
#      'exchange': 'NYSE',
#      'lastday_price': '49.3',
#      'market_value': '247.65',
#      'qty': '5',
#      'side': 'long',
#      'symbol': 'USB',
#      'unrealized_intraday_pl': '1.15',
#      'unrealized_intraday_plpc': '0.0046653144016227',
#      'unrealized_pl': '-9.15',
#      'unrealized_plpc': '-0.0356308411214953'}),
#  Position({   'asset_class': 'us_equity',
#      'asset_id': 'e28f2c45-0bb1-45c1-84e0-f8d1a98c4088',
#      'avg_entry_price': '166.58',
#      'change_today': '0.0005409304002885',
#      'cost_basis': '832.9',
#      'current_price': '166.47',
#      'exchange': 'NYSE',
#      'lastday_price': '166.38',
#      'market_value': '832.35',
#      'qty': '5',
#      'side': 'long',
#      'symbol': 'UNP',
#      'unrealized_intraday_pl': '0.45',
#      'unrealized_intraday_plpc': '0.0005409304002885',
#      'unrealized_pl': '-0.55',
#      'unrealized_plpc': '-0.0006603433785568'}),
#  Position({   'asset_class': 'us_equity',
#      'asset_id': '98dbc012-8ca2-4e68-b2f7-464fdc9bbf3c',
#      'avg_entry_price': '83.98',
#      'change_today': '0.0131314326274695',
#      'cost_basis': '419.9',
#      'current_price': '85.64',
#      'exchange': 'NASDAQ',
#      'lastday_price': '84.53',
#      'market_value': '428.2',
#      'qty': '5',
#      'side': 'long',
#      'symbol': 'UAL',
#      'unrealized_intraday_pl': '5.55',
#      'unrealized_intraday_plpc': '0.0131314326274695',
#      'unrealized_pl': '8.3',
#      'unrealized_plpc': '0.0197666110978804'}),
#  Position({   'asset_class': 'us_equity',
#      'asset_id': '0b3b63d1-09bb-410c-b2ff-e413d3c4f4e6',
#      'avg_entry_price': '22.37',
#      'change_today': '0.00140383715489',
#      'cost_basis': '111.85',
#      'current_price': '21.4',
#      'exchange': 'NYSE',
#      'lastday_price': '21.37',
#      'market_value': '107',
#      'qty': '5',
#      'side': 'long',
#      'symbol': 'UAA',
#      'unrealized_intraday_pl': '0.15',
#      'unrealized_intraday_plpc': '0.00140383715489',
#      'unrealized_pl': '-4.85',
#      'unrealized_plpc': '-0.0433616450603487'}),
#  Position({   'asset_class': 'us_equity',
#      'asset_id': '440efabf-b53c-4d70-b6e5-abb4f53e7104',
#      'avg_entry_price': '106.47',
#      'change_today': '-0.0025237142111217',
#      'cost_basis': '532.35',
#      'current_price': '114.62',
#      'exchange': 'NASDAQ',
#      'lastday_price': '114.91',
#      'market_value': '573.1',
#      'qty': '5',
#      'side': 'long',
#      'symbol': 'TXN',
#      'unrealized_intraday_pl': '-1.45',
#      'unrealized_intraday_plpc': '-0.0025237142111217',
#      'unrealized_pl': '40.75',
#      'unrealized_plpc': '0.0765473842396919'}),
#  Position({   'asset_class': 'us_equity',
#      'asset_id': '2e91ded3-a6d8-423f-bbf0-e0a7f29b88ce',
#      'avg_entry_price': '30.31',
#      'change_today': '-0.0069084628670121',
#      'cost_basis': '151.55',
#      'current_price': '34.5',
#      'exchange': 'NYSE',
#      'lastday_price': '34.74',
#      'market_value': '172.5',
#      'qty': '5',
#      'side': 'long',
#      'symbol': 'TWTR',
#      'unrealized_intraday_pl': '-1.2',
#      'unrealized_intraday_plpc': '-0.0069084628670121',
#      'unrealized_pl': '20.95',
#      'unrealized_plpc': '0.1382382052128011'}),
#  Position({   'asset_class': 'us_equity',
#      'asset_id': '56d817c9-7955-400f-85cf-aa1d1a20bad2',
#      'avg_entry_price': '94.04',
#      'change_today': '0',
#      'cost_basis': '470.2',
#      'current_price': '98.22',
#      'exchange': 'NYSE',
#      'lastday_price': '98.22',
#      'market_value': '491.1',
#      'qty': '5',
#      'side': 'long',
#      'symbol': 'TSS',
#      'unrealized_intraday_pl': '0',
#      'unrealized_intraday_plpc': '0',
#      'unrealized_pl': '20.9',
#      'unrealized_plpc': '0.0444491705657167'}),
#  Position({   'asset_class': 'us_equity',
#      'asset_id': '73caedb2-6646-4666-8891-88b9718bd235',
#      'avg_entry_price': '61.9',
#      'change_today': '0.0062270025474101',
#      'cost_basis': '309.5',
#      'current_price': '71.1',
#      'exchange': 'NYSE',
#      'lastday_price': '70.66',
#      'market_value': '355.5',
#      'qty': '5',
#      'side': 'long',
#      'symbol': 'TSN',
#      'unrealized_intraday_pl': '2.2',
#      'unrealized_intraday_plpc': '0.0062270025474101',
#      'unrealized_pl': '46',
#      'unrealized_plpc': '0.148626817447496'}),
#  Position({   'asset_class': 'us_equity',
#      'asset_id': 'b599b102-254e-4a5c-838d-8cf26857e562',
#      'avg_entry_price': '34.58',
#      'change_today': '-0.0125748502994012',
#      'cost_basis': '172.9',
#      'current_price': '32.98',
#      'exchange': 'NYSE',
#      'lastday_price': '33.4',
#      'market_value': '164.9',
#      'qty': '5',
#      'side': 'long',
#      'symbol': 'TPR',
#      'unrealized_intraday_pl': '-2.1',
#      'unrealized_intraday_plpc': '-0.0125748502994012',
#      'unrealized_pl': '-8',
#      'unrealized_plpc': '-0.0462695199537305'}),
#  Position({   'asset_class': 'us_equity',
#      'asset_id': '722b2e6d-2b85-4502-8f72-55f199fb3c47',
#      'avg_entry_price': '259.48',
#      'change_today': '0.0025820333512641',
#      'cost_basis': '1297.4',
#      'current_price': '279.57',
#      'exchange': 'NYSE',
#      'lastday_price': '278.85',
#      'market_value': '1397.85',
#      'qty': '5',
#      'side': 'long',
#      'symbol': 'TMO',
#      'unrealized_intraday_pl': '3.6',
#      'unrealized_intraday_plpc': '0.0025820333512641',
#      'unrealized_pl': '100.45',
#      'unrealized_plpc': '0.0774240789270849'}),
#  Position({   'asset_class': 'us_equity',
#      'asset_id': '1168e42c-a598-4ed9-8371-2033a0f6af54',
#      'avg_entry_price': '51.37',
#      'change_today': '-0.0082659808963997',
#      'cost_basis': '256.85',
#      'current_price': '53.99',
#      'exchange': 'NYSE',
#      'lastday_price': '54.44',
#      'market_value': '269.95',
#      'qty': '5',
#      'side': 'long',
#      'symbol': 'TJX',
#      'unrealized_intraday_pl': '-2.25',
#      'unrealized_intraday_plpc': '-0.0082659808963997',
#      'unrealized_pl': '13.1',
#      'unrealized_plpc': '0.0510025306599182'}),
#  Position({   'asset_class': 'us_equity',
#      'asset_id': '2d6ed211-6d9b-46d9-b9d5-d3f8b453fd9a',
#      'avg_entry_price': '29.78',
#      'change_today': '0.0106649937264743',
#      'cost_basis': '148.9',
#      'current_price': '32.22',
#      'exchange': 'NYSE',
#      'lastday_price': '31.88',
#      'market_value': '161.1',
#      'qty': '5',
#      'side': 'long',
#      'symbol': 'T',
#      'unrealized_intraday_pl': '1.7',
#      'unrealized_intraday_plpc': '0.0106649937264743',
#      'unrealized_pl': '12.2',
#      'unrealized_plpc': '0.0819341840161182'}),
#  Position({   'asset_class': 'us_equity',
#      'asset_id': '7cf24743-64d1-44cc-99d9-3f08470ad235',
#      'avg_entry_price': '46.386',
#      'change_today': '-0.0072405470635559',
#      'cost_basis': '231.93',
#      'current_price': '49.36',
#      'exchange': 'NASDAQ',
#      'lastday_price': '49.72',
#      'market_value': '246.8',
#      'qty': '5',
#      'side': 'long',
#      'symbol': 'STX',
#      'unrealized_intraday_pl': '-1.8',
#      'unrealized_intraday_plpc': '-0.0072405470635559',
#      'unrealized_pl': '14.87',
#      'unrealized_plpc': '0.0641141723795973'}),
#  Position({   'asset_class': 'us_equity',
#      'asset_id': '10f7d07f-0811-42bf-a780-b4d4cb53eb91',
#      'avg_entry_price': '199.31',
#      'change_today': '0.0014103709275539',
#      'cost_basis': '996.55',
#      'current_price': '213.01',
#      'exchange': 'NYSE',
#      'lastday_price': '212.71',
#      'market_value': '1065.05',
#      'qty': '5',
#      'side': 'long',
#      'symbol': 'SPGI',
#      'unrealized_intraday_pl': '1.5',
#      'unrealized_intraday_plpc': '0.0014103709275539',
#      'unrealized_pl': '68.5',
#      'unrealized_plpc': '0.0687371431438463'}),
#  Position({   'asset_class': 'us_equity',
#      'asset_id': 'e8910749-f3bc-4c48-99ed-0b18c2ba3b15',
#      'avg_entry_price': '46.21',
#      'change_today': '0.0055974165769645',
#      'cost_basis': '231.05',
#      'current_price': '46.71',
#      'exchange': 'NYSE',
#      'lastday_price': '46.45',
#      'market_value': '233.55',
#      'qty': '5',
#      'side': 'long',
#      'symbol': 'SEE',
#      'unrealized_intraday_pl': '1.3',
#      'unrealized_intraday_plpc': '0.0055974165769645',
#      'unrealized_pl': '2.5',
#      'unrealized_plpc': '0.0108201687946332'}),
#  Position({   'asset_class': 'us_equity',
#      'asset_id': 'ee55892a-1ff0-4ede-87e4-ad5aa5998044',
#      'avg_entry_price': '100.96',
#      'change_today': '-0.0075757575757576',
#      'cost_basis': '504.8',
#      'current_price': '100.87',
#      'exchange': 'NYSE',
#      'lastday_price': '101.64',
#      'market_value': '504.35',
#      'qty': '5',
#      'side': 'long',
#      'symbol': 'RMD',
#      'unrealized_intraday_pl': '-3.85',
#      'unrealized_intraday_plpc': '-0.0075757575757576',
#      'unrealized_pl': '-0.45',
#      'unrealized_plpc': '-0.000891442155309'}),
#  Position({   'asset_class': 'us_equity',
#      'asset_id': '6431ab56-4841-415d-9a71-2d0e19b940a9',
#      'avg_entry_price': '67.23',
#      'change_today': '0.0114329268292683',
#      'cost_basis': '336.15',
#      'current_price': '66.35',
#      'exchange': 'NYSE',
#      'lastday_price': '65.6',
#      'market_value': '331.75',
#      'qty': '5',
#      'side': 'long',
#      'symbol': 'RHI',
#      'unrealized_intraday_pl': '3.75',
#      'unrealized_intraday_plpc': '0.0114329268292683',
#      'unrealized_pl': '-4.4',
#      'unrealized_plpc': '-0.013089394615499'}),
#  Position({   'asset_class': 'us_equity',
#      'asset_id': '39be1334-06b6-4df2-a2f1-b21b942628d0',
#      'avg_entry_price': '53.53',
#      'change_today': '-0.0062133854074206',
#      'cost_basis': '267.65',
#      'current_price': '55.98',
#      'exchange': 'NASDAQ',
#      'lastday_price': '56.33',
#      'market_value': '279.9',
#      'qty': '5',
#      'side': 'long',
#      'symbol': 'QCOM',
#      'unrealized_intraday_pl': '-1.75',
#      'unrealized_intraday_plpc': '-0.0062133854074206',
#      'unrealized_pl': '12.25',
#      'unrealized_plpc': '0.0457687278161778'}),
#  Position({   'asset_class': 'us_equity',
#      'asset_id': '24cbba8c-831b-44e2-8503-dd0c2ed7af8f',
#      'avg_entry_price': '96.08',
#      'change_today': '-0.0122767857142857',
#      'cost_basis': '480.4',
#      'current_price': '106.2',
#      'exchange': 'NASDAQ',
#      'lastday_price': '107.52',
#      'market_value': '531',
#      'qty': '5',
#      'side': 'long',
#      'symbol': 'PYPL',
#      'unrealized_intraday_pl': '-6.6',
#      'unrealized_intraday_plpc': '-0.0122767857142857',
#      'unrealized_pl': '50.6',
#      'unrealized_plpc': '0.1053288925895087'}),
#  Position({   'asset_class': 'us_equity',
#      'asset_id': '2ebe177b-c523-4c1f-9276-8f0759a67a52',
#      'avg_entry_price': '32.1',
#      'change_today': '0.0009448818897638',
#      'cost_basis': '160.5',
#      'current_price': '31.78',
#      'exchange': 'NYSE',
#      'lastday_price': '31.75',
#      'market_value': '158.9',
#      'qty': '5',
#      'side': 'long',
#      'symbol': 'PPL',
#      'unrealized_intraday_pl': '0.15',
#      'unrealized_intraday_plpc': '0.0009448818897638',
#      'unrealized_pl': '-1.6',
#      'unrealized_plpc': '-0.0099688473520249'}),
#  Position({   'asset_class': 'us_equity',
#      'asset_id': 'b19c4863-d517-4472-9236-8864e50dfa3e',
#      'avg_entry_price': '86.97',
#      'change_today': '-0.0012832477834811',
#      'cost_basis': '434.85',
#      'current_price': '85.61',
#      'exchange': 'NYSE',
#      'lastday_price': '85.72',
#      'market_value': '428.05',
#      'qty': '5',
#      'side': 'long',
#      'symbol': 'PM',
#      'unrealized_intraday_pl': '-0.55',
#      'unrealized_intraday_plpc': '-0.0012832477834811',
#      'unrealized_pl': '-6.8',
#      'unrealized_plpc': '-0.0156375761756928'}),
#  Position({   'asset_class': 'us_equity',
#      'asset_id': '32d00bae-5f6a-4712-9c18-3a007524fa3f',
#      'avg_entry_price': '69.89',
#      'change_today': '-0.00163132137031',
#      'cost_basis': '349.45',
#      'current_price': '73.44',
#      'exchange': 'NYSE',
#      'lastday_price': '73.56',
#      'market_value': '367.2',
#      'qty': '5',
#      'side': 'long',
#      'symbol': 'PLD',
#      'unrealized_intraday_pl': '-0.6',
#      'unrealized_intraday_plpc': '-0.00163132137031',
#      'unrealized_pl': '17.75',
#      'unrealized_plpc': '0.0507941050221777'}),
#  Position({   'asset_class': 'us_equity',
#      'asset_id': '44de3ac7-fd5e-4c49-99ae-561246d323f5',
#      'avg_entry_price': '174.18',
#      'change_today': '0.0131104555883317',
#      'cost_basis': '870.9',
#      'current_price': '185.46',
#      'exchange': 'NYSE',
#      'lastday_price': '183.06',
#      'market_value': '927.3',
#      'qty': '5',
#      'side': 'long',
#      'symbol': 'PH',
#      'unrealized_intraday_pl': '12',
#      'unrealized_intraday_plpc': '0.0131104555883317',
#      'unrealized_pl': '56.4',
#      'unrealized_plpc': '0.064760592490527'}),
#  Position({   'asset_class': 'us_equity',
#      'asset_id': '7e23958d-28fe-4f5e-acb0-159831a769ed',
#      'avg_entry_price': '72.28',
#      'change_today': '-0.0048563896212016',
#      'cost_basis': '361.4',
#      'current_price': '71.72',
#      'exchange': 'NYSE',
#      'lastday_price': '72.07',
#      'market_value': '358.6',
#      'qty': '5',
#      'side': 'long',
#      'symbol': 'PGR',
#      'unrealized_intraday_pl': '-1.75',
#      'unrealized_intraday_plpc': '-0.0048563896212016',
#      'unrealized_pl': '-2.8',
#      'unrealized_plpc': '-0.0077476480354178'}),
#  Position({   'asset_class': 'us_equity',
#      'asset_id': 'f81a406b-a53c-4ea5-ab05-6fb92bfc6bd7',
#      'avg_entry_price': '98.34',
#      'change_today': '-0.0001910949742022',
#      'cost_basis': '491.7',
#      'current_price': '104.64',
#      'exchange': 'NYSE',
#      'lastday_price': '104.66',
#      'market_value': '523.2',
#      'qty': '5',
#      'side': 'long',
#      'symbol': 'PG',
#      'unrealized_intraday_pl': '-0.1',
#      'unrealized_intraday_plpc': '-0.0001910949742022',
#      'unrealized_pl': '31.5',
#      'unrealized_plpc': '0.0640634533251983'}),
#  Position({   'asset_class': 'us_equity',
#      'asset_id': '7b7466c4-5066-4e3e-80e6-8da1c835ce56',
#      'avg_entry_price': '115.83',
#      'change_today': '-0.0057362943538474',
#      'cost_basis': '579.15',
#      'current_price': '121.33',
#      'exchange': 'NASDAQ',
#      'lastday_price': '122.03',
#      'market_value': '606.65',
#      'qty': '5',
#      'side': 'long',
#      'symbol': 'PEP',
#      'unrealized_intraday_pl': '-3.5',
#      'unrealized_intraday_plpc': '-0.0057362943538474',
#      'unrealized_pl': '27.5',
#      'unrealized_plpc': '0.0474833808167142'}),
#  Position({   'asset_class': 'us_equity',
#      'asset_id': '7f712a83-dc6a-4d5d-bf2a-c52705a06905',
#      'avg_entry_price': '59.18',
#      'change_today': '-0.0023537323470074',
#      'cost_basis': '295.9',
#      'current_price': '59.34',
#      'exchange': 'NYSE',
#      'lastday_price': '59.48',
#      'market_value': '296.7',
#      'qty': '5',
#      'side': 'long',
#      'symbol': 'PEG',
#      'unrealized_intraday_pl': '-0.7',
#      'unrealized_intraday_plpc': '-0.0023537323470074',
#      'unrealized_pl': '0.8',
#      'unrealized_plpc': '0.0027036160865157'}),
#  Position({   'asset_class': 'us_equity',
#      'asset_id': '27982558-2464-4daf-bb2f-b3b728659884',
#      'avg_entry_price': '51.85',
#      'change_today': '-0.0029640607632456',
#      'cost_basis': '259.25',
#      'current_price': '53.82',
#      'exchange': 'NYSE',
#      'lastday_price': '53.98',
#      'market_value': '269.1',
#      'qty': '5',
#      'side': 'long',
#      'symbol': 'ORCL',
#      'unrealized_intraday_pl': '-0.8',
#      'unrealized_intraday_plpc': '-0.0029640607632456',
#      'unrealized_pl': '9.85',
#      'unrealized_plpc': '0.0379942140790743'}),
#  Position({   'asset_class': 'us_equity',
#      'asset_id': '1b3dea47-c70a-4a67-8c2d-a2007d06d8cd',
#      'avg_entry_price': '65.05',
#      'change_today': '0.0002864098524989',
#      'cost_basis': '325.25',
#      'current_price': '69.85',
#      'exchange': 'NYSE',
#      'lastday_price': '69.83',
#      'market_value': '349.25',
#      'qty': '5',
#      'side': 'long',
#      'symbol': 'OKE',
#      'unrealized_intraday_pl': '0.1',
#      'unrealized_intraday_plpc': '0.0002864098524989',
#      'unrealized_pl': '24',
#      'unrealized_plpc': '0.0737893927747886'}),
#  Position({   'asset_class': 'us_equity',
#      'asset_id': '51dc5fc6-c891-4293-a435-f09ca03dcfc4',
#      'avg_entry_price': '15.92',
#      'change_today': '-0.0077569489334195',
#      'cost_basis': '79.6',
#      'current_price': '15.35',
#      'exchange': 'NASDAQ',
#      'lastday_price': '15.47',
#      'market_value': '76.75',
#      'qty': '5',
#      'side': 'long',
#      'symbol': 'NWL',
#      'unrealized_intraday_pl': '-0.6',
#      'unrealized_intraday_plpc': '-0.0077569489334195',
#      'unrealized_pl': '-2.85',
#      'unrealized_plpc': '-0.0358040201005025'}),
#  Position({   'asset_class': 'us_equity',
#      'asset_id': '4ce9353c-66d1-46c2-898f-fce867ab0247',
#      'avg_entry_price': '156.07',
#      'change_today': '-0.005152224824356',
#      'cost_basis': '780.35',
#      'current_price': '191.16',
#      'exchange': 'NASDAQ',
#      'lastday_price': '192.15',
#      'market_value': '955.8',
#      'qty': '5',
#      'side': 'long',
#      'symbol': 'NVDA',
#      'unrealized_intraday_pl': '-4.95',
#      'unrealized_intraday_plpc': '-0.005152224824356',
#      'unrealized_pl': '175.45',
#      'unrealized_plpc': '0.224835009931441'}),
#  Position({   'asset_class': 'us_equity',
#      'asset_id': '3c3a99ab-4500-4f14-8f23-50a01d3019b1',
#      'avg_entry_price': '60.33',
#      'change_today': '-0.0120192307692308',
#      'cost_basis': '301.65',
#      'current_price': '57.54',
#      'exchange': 'NYSE',
#      'lastday_price': '58.24',
#      'market_value': '287.7',
#      'qty': '5',
#      'side': 'long',
#      'symbol': 'NUE',
#      'unrealized_intraday_pl': '-3.5',
#      'unrealized_intraday_plpc': '-0.0120192307692308',
#      'unrealized_pl': '-13.95',
#      'unrealized_plpc': '-0.0462456489308802'}),
#  Position({   'asset_class': 'us_equity',
#      'asset_id': 'd37df28f-5646-48c8-99cc-4d0c9a5ec9ff',
#      'avg_entry_price': '64.61',
#      'change_today': '0.0153535353535354',
#      'cost_basis': '323.05',
#      'current_price': '75.39',
#      'exchange': 'NASDAQ',
#      'lastday_price': '74.25',
#      'market_value': '376.95',
#      'qty': '5',
#      'side': 'long',
#      'symbol': 'NTAP',
#      'unrealized_intraday_pl': '5.7',
#      'unrealized_intraday_plpc': '0.0153535353535354',
#      'unrealized_pl': '53.9',
#      'unrealized_plpc': '0.1668472372697725'}),
#  Position({   'asset_class': 'us_equity',
#      'asset_id': 'db00f7c3-19bb-42b6-9beb-79e92487f99e',
#      'avg_entry_price': '85.63',
#      'change_today': '0.0011779950524208',
#      'cost_basis': '428.15',
#      'current_price': '84.99',
#      'exchange': 'NYSE',
#      'lastday_price': '84.89',
#      'market_value': '424.95',
#      'qty': '5',
#      'side': 'long',
#      'symbol': 'NKE',
#      'unrealized_intraday_pl': '0.5',
#      'unrealized_intraday_plpc': '0.0011779950524208',
#      'unrealized_pl': '-3.2',
#      'unrealized_plpc': '-0.0074740161158472'}),
#  Position({   'asset_class': 'us_equity',
#      'asset_id': 'bb2a26c0-4c77-4801-8afc-82e8142ac7b8',
#      'avg_entry_price': '350.6',
#      'change_today': '0.0113202362961945',
#      'cost_basis': '1753',
#      'current_price': '368.07',
#      'exchange': 'NASDAQ',
#      'lastday_price': '363.95',
#      'market_value': '1840.35',
#      'qty': '5',
#      'side': 'long',
#      'symbol': 'NFLX',
#      'unrealized_intraday_pl': '20.6',
#      'unrealized_intraday_plpc': '0.0113202362961945',
#      'unrealized_pl': '87.35',
#      'unrealized_plpc': '0.0498288648031945'}),
#  Position({   'asset_class': 'us_equity',
#      'asset_id': '96da6121-b5ab-4f8b-bb53-60ae53cb5ed3',
#      'avg_entry_price': '34.03',
#      'change_today': '-0.0132377275234418',
#      'cost_basis': '170.15',
#      'current_price': '35.78',
#      'exchange': 'NYSE',
#      'lastday_price': '36.26',
#      'market_value': '178.9',
#      'qty': '5',
#      'side': 'long',
#      'symbol': 'NEM',
#      'unrealized_intraday_pl': '-2.4',
#      'unrealized_intraday_plpc': '-0.0132377275234418',
#      'unrealized_pl': '8.75',
#      'unrealized_plpc': '0.0514252130473112'}),
#  Position({   'asset_class': 'us_equity',
#      'asset_id': '1ef18995-5094-4f62-a5c5-e00168611152',
#      'avg_entry_price': '41.04',
#      'change_today': '0.0045045045045045',
#      'cost_basis': '205.2',
#      'current_price': '42.37',
#      'exchange': 'NASDAQ',
#      'lastday_price': '42.18',
#      'market_value': '211.85',
#      'qty': '5',
#      'side': 'long',
#      'symbol': 'MU',
#      'unrealized_intraday_pl': '0.95',
#      'unrealized_intraday_plpc': '0.0045045045045045',
#      'unrealized_pl': '6.65',
#      'unrealized_plpc': '0.0324074074074074'}),
#  Position({   'asset_class': 'us_equity',
#      'asset_id': 'b6d1aa75-5c9c-4353-a305-9e2caa1925ab',
#      'avg_entry_price': '111.41',
#      'change_today': '-0.0017467975378473',
#      'cost_basis': '557.05',
#      'current_price': '120.01',
#      'exchange': 'NASDAQ',
#      'lastday_price': '120.22',
#      'market_value': '600.05',
#      'qty': '5',
#      'side': 'long',
#      'symbol': 'MSFT',
#      'unrealized_intraday_pl': '-1.05',
#      'unrealized_intraday_plpc': '-0.0017467975378473',
#      'unrealized_pl': '43',
#      'unrealized_plpc': '0.0771923525715824'}),
#  Position({   'asset_class': 'us_equity',
#      'asset_id': 'cf29c5fe-b808-4e87-be3b-6a10d1f67778',
#      'avg_entry_price': '17.08',
#      'change_today': '-0.0148911798396334',
#      'cost_basis': '85.4',
#      'current_price': '17.2',
#      'exchange': 'NYSE',
#      'lastday_price': '17.46',
#      'market_value': '86',
#      'qty': '5',
#      'side': 'long',
#      'symbol': 'MRO',
#      'unrealized_intraday_pl': '-1.3',
#      'unrealized_intraday_plpc': '-0.0148911798396334',
#      'unrealized_pl': '0.6',
#      'unrealized_plpc': '0.0070257611241218'}),
#  Position({   'asset_class': 'us_equity',
#      'asset_id': '0d56791f-7395-40fa-853b-7b852bd9a7bf',
#      'avg_entry_price': '80.84',
#      'change_today': '-0.0116307844592923',
#      'cost_basis': '404.2',
#      'current_price': '79.88',
#      'exchange': 'NYSE',
#      'lastday_price': '80.82',
#      'market_value': '399.4',
#      'qty': '5',
#      'side': 'long',
#      'symbol': 'MRK',
#      'unrealized_intraday_pl': '-4.7',
#      'unrealized_intraday_plpc': '-0.0116307844592923',
#      'unrealized_pl': '-4.8',
#      'unrealized_plpc': '-0.0118753092528451'}),
#  Position({   'asset_class': 'us_equity',
#      'asset_id': '6c285ed0-024c-47f7-9e2a-8fb08e6913ac',
#      'avg_entry_price': '30.6',
#      'change_today': '-0.0116959064327485',
#      'cost_basis': '153',
#      'current_price': '27.04',
#      'exchange': 'NYSE',
#      'lastday_price': '27.36',
#      'market_value': '135.2',
#      'qty': '5',
#      'side': 'long',
#      'symbol': 'MOS',
#      'unrealized_intraday_pl': '-1.6',
#      'unrealized_intraday_plpc': '-0.0116959064327485',
#      'unrealized_pl': '-17.8',
#      'unrealized_plpc': '-0.1163398692810458'}),
#  Position({   'asset_class': 'us_equity',
#      'asset_id': '4eb91cfa-4f8b-4df5-acb7-2f3434fa283f',
#      'avg_entry_price': '55',
#      'change_today': '0.0057720057720058',
#      'cost_basis': '275',
#      'current_price': '55.76',
#      'exchange': 'NYSE',
#      'lastday_price': '55.44',
#      'market_value': '278.8',
#      'qty': '5',
#      'side': 'long',
#      'symbol': 'MO',
#      'unrealized_intraday_pl': '1.6',
#      'unrealized_intraday_plpc': '0.0057720057720058',
#      'unrealized_pl': '3.8',
#      'unrealized_plpc': '0.0138181818181818'}),
#  Position({   'asset_class': 'us_equity',
#      'asset_id': '45c52e44-2c57-4886-9ec0-be254b4a8590',
#      'avg_entry_price': '151.1',
#      'change_today': '-0.0049152761609106',
#      'cost_basis': '755.5',
#      'current_price': '153.86',
#      'exchange': 'NYSE',
#      'lastday_price': '154.62',
#      'market_value': '769.3',
#      'qty': '5',
#      'side': 'long',
#      'symbol': 'MKC',
#      'unrealized_intraday_pl': '-3.8',
#      'unrealized_intraday_plpc': '-0.0049152761609106',
#      'unrealized_pl': '13.8',
#      'unrealized_plpc': '0.0182660489741893'}),
#  Position({   'asset_class': 'us_equity',
#      'asset_id': '705ec4dc-73b9-42fc-8b17-d4e13c31cfae',
#      'avg_entry_price': '46.88',
#      'change_today': '-0.0032193158953722',
#      'cost_basis': '234.4',
#      'current_price': '49.54',
#      'exchange': 'NASDAQ',
#      'lastday_price': '49.7',
#      'market_value': '247.7',
#      'qty': '5',
#      'side': 'long',
#      'symbol': 'MDLZ',
#      'unrealized_intraday_pl': '-0.8',
#      'unrealized_intraday_plpc': '-0.0032193158953722',
#      'unrealized_pl': '13.3',
#      'unrealized_plpc': '0.056740614334471'}),
#  Position({   'asset_class': 'us_equity',
#      'asset_id': '8ace7574-1e55-48d9-bf01-90f4d0f9589d',
#      'avg_entry_price': '14.85',
#      'change_today': '0',
#      'cost_basis': '74.25',
#      'current_price': '13.5',
#      'exchange': 'NASDAQ',
#      'lastday_price': '13.5',
#      'market_value': '67.5',
#      'qty': '5',
#      'side': 'long',
#      'symbol': 'MAT',
#      'unrealized_intraday_pl': '0',
#      'unrealized_intraday_plpc': '0',
#      'unrealized_pl': '-6.75',
#      'unrealized_plpc': '-0.0909090909090909'}),
#  Position({   'asset_class': 'us_equity',
#      'asset_id': '3d9e6406-e27a-4c27-a898-ab1670650b5a',
#      'avg_entry_price': '39.83',
#      'change_today': '-0.0049492699826776',
#      'cost_basis': '199.15',
#      'current_price': '40.21',
#      'exchange': 'NYSE',
#      'lastday_price': '40.41',
#      'market_value': '201.05',
#      'qty': '5',
#      'side': 'long',
#      'symbol': 'MAS',
#      'unrealized_intraday_pl': '-1',
#      'unrealized_intraday_plpc': '-0.0049492699826776',
#      'unrealized_pl': '1.9',
#      'unrealized_plpc': '0.0095405473261361'}),
#  Position({   'asset_class': 'us_equity',
#      'asset_id': 'bd10e4a3-a39d-4726-91cd-8b4d68a635ab',
#      'avg_entry_price': '123.26',
#      'change_today': '0.0020338983050847',
#      'cost_basis': '616.3',
#      'current_price': '133.02',
#      'exchange': 'NASDAQ',
#      'lastday_price': '132.75',
#      'market_value': '665.1',
#      'qty': '5',
#      'side': 'long',
#      'symbol': 'MAR',
#      'unrealized_intraday_pl': '1.35',
#      'unrealized_intraday_plpc': '0.0020338983050847',
#      'unrealized_pl': '48.8',
#      'unrealized_plpc': '0.0791822164530261'}),
#  Position({   'asset_class': 'us_equity',
#      'asset_id': 'e930cf4f-6b04-4a7e-85e6-ad1b01cd3c17',
#      'avg_entry_price': '53.61',
#      'change_today': '0.0053211706575447',
#      'cost_basis': '268.05',
#      'current_price': '52.9',
#      'exchange': 'NYSE',
#      'lastday_price': '52.62',
#      'market_value': '264.5',
#      'qty': '5',
#      'side': 'long',
#      'symbol': 'LUV',
#      'unrealized_intraday_pl': '1.4',
#      'unrealized_intraday_plpc': '0.0053211706575447',
#      'unrealized_pl': '-3.55',
#      'unrealized_plpc': '-0.0132437977989181'}),
#  Position({   'asset_class': 'us_equity',
#      'asset_id': 'a6ffe329-5ea3-4bb8-b58a-06ed1432dd50',
#      'avg_entry_price': '102.92',
#      'change_today': '0.0110740024608894',
#      'cost_basis': '514.6',
#      'current_price': '115.04',
#      'exchange': 'NYSE',
#      'lastday_price': '113.78',
#      'market_value': '575.2',
#      'qty': '5',
#      'side': 'long',
#      'symbol': 'LOW',
#      'unrealized_intraday_pl': '6.3',
#      'unrealized_intraday_plpc': '0.0110740024608894',
#      'unrealized_pl': '60.6',
#      'unrealized_plpc': '0.1177613680528566'}),
#  Position({   'asset_class': 'us_equity',
#      'asset_id': '87266a27-1b34-47bd-b236-bd3a9f59b138',
#      'avg_entry_price': '126.52',
#      'change_today': '-0.0165867463249745',
#      'cost_basis': '632.6',
#      'current_price': '125.1',
#      'exchange': 'NYSE',
#      'lastday_price': '127.21',
#      'market_value': '625.5',
#      'qty': '5',
#      'side': 'long',
#      'symbol': 'LLY',
#      'unrealized_intraday_pl': '-10.55',
#      'unrealized_intraday_plpc': '-0.0165867463249745',
#      'unrealized_pl': '-7.1',
#      'unrealized_plpc': '-0.0112235219728106'}),
#  Position({   'asset_class': 'us_equity',
#      'asset_id': 'e88363a4-d92a-42a2-bc42-eb7ecce50374',
#      'avg_entry_price': '27.92',
#      'change_today': '0.0009891196834817',
#      'cost_basis': '139.6',
#      'current_price': '30.36',
#      'exchange': 'NASDAQ',
#      'lastday_price': '30.33',
#      'market_value': '151.8',
#      'qty': '5',
#      'side': 'long',
#      'symbol': 'LKQ',
#      'unrealized_intraday_pl': '0.15',
#      'unrealized_intraday_plpc': '0.0009891196834817',
#      'unrealized_pl': '12.2',
#      'unrealized_plpc': '0.0873925501432665'}),
#  Position({   'asset_class': 'us_equity',
#      'asset_id': 'b06e3c34-c4a4-4d44-a376-a4baae5974ac',
#      'avg_entry_price': '167.76',
#      'change_today': '-0.0058527966429242',
#      'cost_basis': '838.8',
#      'current_price': '180.05',
#      'exchange': 'NYSE',
#      'lastday_price': '181.11',
#      'market_value': '900.25',
#      'qty': '5',
#      'side': 'long',
#      'symbol': 'LIN',
#      'unrealized_intraday_pl': '-5.3',
#      'unrealized_intraday_plpc': '-0.0058527966429242',
#      'unrealized_pl': '61.45',
#      'unrealized_plpc': '0.0732594182164998'}),
#  Position({   'asset_class': 'us_equity',
#      'asset_id': '95ae860b-4cf1-4dfe-9159-9bd4cd3c7915',
#      'avg_entry_price': '51.54',
#      'change_today': '0.0090462143559489',
#      'cost_basis': '257.7',
#      'current_price': '51.31',
#      'exchange': 'NYSE',
#      'lastday_price': '50.85',
#      'market_value': '256.55',
#      'qty': '5',
#      'side': 'long',
#      'symbol': 'LEN',
#      'unrealized_intraday_pl': '2.3',
#      'unrealized_intraday_plpc': '0.0090462143559489',
#      'unrealized_pl': '-1.15',
#      'unrealized_plpc': '-0.0044625533566162'}),
#  Position({   'asset_class': 'us_equity',
#      'asset_id': '225a5e8a-938e-4a95-8bcb-3989a3df618d',
#      'avg_entry_price': '48.05',
#      'change_today': '0.0096548890714873',
#      'cost_basis': '240.25',
#      'current_price': '49.15',
#      'exchange': 'NYSE',
#      'lastday_price': '48.68',
#      'market_value': '245.75',
#      'qty': '5',
#      'side': 'long',
#      'symbol': 'L',
#      'unrealized_intraday_pl': '2.35',
#      'unrealized_intraday_plpc': '0.0096548890714873',
#      'unrealized_pl': '5.5',
#      'unrealized_plpc': '0.0228928199791883'}),
#  Position({   'asset_class': 'us_equity',
#      'asset_id': 'e47acf22-5340-477a-a3ac-020b1ed34d12',
#      'avg_entry_price': '19.61',
#      'change_today': '0.0025201612903226',
#      'cost_basis': '98.05',
#      'current_price': '19.89',
#      'exchange': 'NYSE',
#      'lastday_price': '19.84',
#      'market_value': '99.45',
#      'qty': '5',
#      'side': 'long',
#      'symbol': 'KMI',
#      'unrealized_intraday_pl': '0.25',
#      'unrealized_intraday_plpc': '0.0025201612903226',
#      'unrealized_pl': '1.4',
#      'unrealized_plpc': '0.014278429372769'}),
#  Position({   'asset_class': 'us_equity',
#      'asset_id': '9628aa98-ccef-4cca-8e64-6ab0d5a46819',
#      'avg_entry_price': '54.6',
#      'change_today': '-0.00886802295253',
#      'cost_basis': '273',
#      'current_price': '57',
#      'exchange': 'NYSE',
#      'lastday_price': '57.51',
#      'market_value': '285',
#      'qty': '5',
#      'side': 'long',
#      'symbol': 'K',
#      'unrealized_intraday_pl': '-2.55',
#      'unrealized_intraday_plpc': '-0.00886802295253',
#      'unrealized_pl': '12',
#      'unrealized_plpc': '0.043956043956044'}),
#  Position({   'asset_class': 'us_equity',
#      'asset_id': '89312904-5117-4d32-acb1-bcc0c1ba2e74',
#      'avg_entry_price': '26.92',
#      'change_today': '-0.0007275372862859',
#      'cost_basis': '134.6',
#      'current_price': '27.47',
#      'exchange': 'NYSE',
#      'lastday_price': '27.49',
#      'market_value': '137.35',
#      'qty': '5',
#      'side': 'long',
#      'symbol': 'JNPR',
#      'unrealized_intraday_pl': '-0.1',
#      'unrealized_intraday_plpc': '-0.0007275372862859',
#      'unrealized_pl': '2.75',
#      'unrealized_plpc': '0.0204309063893016'}),
#  Position({   'asset_class': 'us_equity',
#      'asset_id': 'd5d0fef5-06f8-49af-a93b-6b4aa52a37db',
#      'avg_entry_price': '22.9',
#      'change_today': '0.0101757631822387',
#      'cost_basis': '114.5',
#      'current_price': '21.84',
#      'exchange': 'NYSE',
#      'lastday_price': '21.62',
#      'market_value': '109.2',
#      'qty': '5',
#      'side': 'long',
#      'symbol': 'IPG',
#      'unrealized_intraday_pl': '1.1',
#      'unrealized_intraday_plpc': '0.0101757631822387',
#      'unrealized_pl': '-5.3',
#      'unrealized_plpc': '-0.0462882096069869'}),
#  Position({   'asset_class': 'us_equity',
#      'asset_id': 'd40b732c-72ca-44e0-a156-28ce00086458',
#      'avg_entry_price': '47.26',
#      'change_today': '0.001065416577882',
#      'cost_basis': '236.3',
#      'current_price': '46.98',
#      'exchange': 'NYSE',
#      'lastday_price': '46.93',
#      'market_value': '234.9',
#      'qty': '5',
#      'side': 'long',
#      'symbol': 'IP',
#      'unrealized_intraday_pl': '0.25',
#      'unrealized_intraday_plpc': '0.001065416577882',
#      'unrealized_pl': '-1.4',
#      'unrealized_plpc': '-0.0059246720270842'}),
#  Position({   'asset_class': 'us_equity',
#      'asset_id': '0cf42aa3-9816-4f1f-aa84-6482ac9303e9',
#      'avg_entry_price': '53.39',
#      'change_today': '0.0001793400286944',
#      'cost_basis': '266.95',
#      'current_price': '55.77',
#      'exchange': 'NASDAQ',
#      'lastday_price': '55.76',
#      'market_value': '278.85',
#      'qty': '5',
#      'side': 'long',
#      'symbol': 'INTC',
#      'unrealized_intraday_pl': '0.05',
#      'unrealized_intraday_plpc': '0.0001793400286944',
#      'unrealized_pl': '11.9',
#      'unrealized_plpc': '0.0445776362614722'}),
#  Position({   'asset_class': 'us_equity',
#      'asset_id': '77832354-b542-4769-b168-1ee930e2d2e9',
#      'avg_entry_price': '307.85',
#      'change_today': '0.009294309543594',
#      'cost_basis': '1539.25',
#      'current_price': '327.95',
#      'exchange': 'NASDAQ',
#      'lastday_price': '324.93',
#      'market_value': '1639.75',
#      'qty': '5',
#      'side': 'long',
#      'symbol': 'ILMN',
#      'unrealized_intraday_pl': '15.1',
#      'unrealized_intraday_plpc': '0.009294309543594',
#      'unrealized_pl': '100.5',
#      'unrealized_plpc': '0.0652915380867306'}),
#  Position({   'asset_class': 'us_equity',
#      'asset_id': '3988b92e-b5ee-449e-a83a-a04bbdf18cff',
#      'avg_entry_price': '213.5',
#      'change_today': '-0.0072570232848048',
#      'cost_basis': '1067.5',
#      'current_price': '222.98',
#      'exchange': 'NASDAQ',
#      'lastday_price': '224.61',
#      'market_value': '1114.9',
#      'qty': '5',
#      'side': 'long',
#      'symbol': 'IDXX',
#      'unrealized_intraday_pl': '-8.15',
#      'unrealized_intraday_plpc': '-0.0072570232848048',
#      'unrealized_pl': '47.4',
#      'unrealized_plpc': '0.0444028103044496'}),
#  Position({   'asset_class': 'us_equity',
#      'asset_id': '8c16ddb4-4722-4c02-848d-e9f022ae0c35',
#      'avg_entry_price': '19.6',
#      'change_today': '-0.008355091383812',
#      'cost_basis': '98',
#      'current_price': '18.99',
#      'exchange': 'NYSE',
#      'lastday_price': '19.15',
#      'market_value': '94.95',
#      'qty': '5',
#      'side': 'long',
#      'symbol': 'HST',
#      'unrealized_intraday_pl': '-0.8',
#      'unrealized_intraday_plpc': '-0.008355091383812',
#      'unrealized_pl': '-3.05',
#      'unrealized_plpc': '-0.0311224489795918'}),
#  Position({   'asset_class': 'us_equity',
#      'asset_id': '1bb0e1f2-1967-4b8d-8f98-30af6505cc6a',
#      'avg_entry_price': '59.19',
#      'change_today': '-0.0184346701164295',
#      'cost_basis': '295.95',
#      'current_price': '60.7',
#      'exchange': 'NASDAQ',
#      'lastday_price': '61.84',
#      'market_value': '303.5',
#      'qty': '5',
#      'side': 'long',
#      'symbol': 'HSIC',
#      'unrealized_intraday_pl': '-5.7',
#      'unrealized_intraday_plpc': '-0.0184346701164295',
#      'unrealized_pl': '7.55',
#      'unrealized_plpc': '0.0255110660584558'}),
#  Position({   'asset_class': 'us_equity',
#      'asset_id': '8e341794-40b2-4509-bca8-c7b6fc49eb96',
#      'avg_entry_price': '19.49',
#      'change_today': '-0.0035035035035035',
#      'cost_basis': '97.45',
#      'current_price': '19.91',
#      'exchange': 'NYSE',
#      'lastday_price': '19.98',
#      'market_value': '99.55',
#      'qty': '5',
#      'side': 'long',
#      'symbol': 'HPQ',
#      'unrealized_intraday_pl': '-0.35',
#      'unrealized_intraday_plpc': '-0.0035035035035035',
#      'unrealized_pl': '2.1',
#      'unrealized_plpc': '0.021549512570549'}),
#  Position({   'asset_class': 'us_equity',
#      'asset_id': '03a4498a-78b3-4043-8dcb-2c3cf4dc352e',
#      'avg_entry_price': '16.09',
#      'change_today': '-0.0006146281499693',
#      'cost_basis': '80.45',
#      'current_price': '16.26',
#      'exchange': 'NYSE',
#      'lastday_price': '16.27',
#      'market_value': '81.3',
#      'qty': '5',
#      'side': 'long',
#      'symbol': 'HPE',
#      'unrealized_intraday_pl': '-0.05',
#      'unrealized_intraday_plpc': '-0.0006146281499693',
#      'unrealized_pl': '0.85',
#      'unrealized_plpc': '0.0105655686761964'}),
#  Position({   'asset_class': 'us_equity',
#      'asset_id': 'c31e63a5-b5a2-417e-9ac3-278b4ff35cb5',
#      'avg_entry_price': '47.14',
#      'change_today': '-0.0042052144659378',
#      'cost_basis': '235.7',
#      'current_price': '47.36',
#      'exchange': 'NASDAQ',
#      'lastday_price': '47.56',
#      'market_value': '236.8',
#      'qty': '5',
#      'side': 'long',
#      'symbol': 'HOLX',
#      'unrealized_intraday_pl': '-1',
#      'unrealized_intraday_plpc': '-0.0042052144659378',
#      'unrealized_pl': '1.1',
#      'unrealized_plpc': '0.0046669495120916'}),
#  Position({   'asset_class': 'us_equity',
#      'asset_id': 'abedb6e6-42eb-4a23-aa05-05ce6500b503',
#      'avg_entry_price': '37.5',
#      'change_today': '-0.0005085176709891',
#      'cost_basis': '187.5',
#      'current_price': '39.31',
#      'exchange': 'NYSE',
#      'lastday_price': '39.33',
#      'market_value': '196.55',
#      'qty': '5',
#      'side': 'long',
#      'symbol': 'HOG',
#      'unrealized_intraday_pl': '-0.1',
#      'unrealized_intraday_plpc': '-0.0005085176709891',
#      'unrealized_pl': '9.05',
#      'unrealized_plpc': '0.0482666666666667'}),
#  Position({   'asset_class': 'us_equity',
#      'asset_id': '072e0811-8f84-4acc-bc3b-95761ea08dd6',
#      'avg_entry_price': '82.86',
#      'change_today': '0.0031818181818182',
#      'cost_basis': '414.3',
#      'current_price': '88.28',
#      'exchange': 'NYSE',
#      'lastday_price': '88',
#      'market_value': '441.4',
#      'qty': '5',
#      'side': 'long',
#      'symbol': 'HLT',
#      'unrealized_intraday_pl': '1.4',
#      'unrealized_intraday_plpc': '0.0031818181818182',
#      'unrealized_pl': '27.1',
#      'unrealized_plpc': '0.0654115375331885'}),
#  Position({   'asset_class': 'us_equity',
#      'asset_id': '945cfc7c-88e3-4db8-9f17-a4889b038cc5',
#      'avg_entry_price': '58.36',
#      'change_today': '-0.0020527396178746',
#      'cost_basis': '291.8',
#      'current_price': '63.2',
#      'exchange': 'NYSE',
#      'lastday_price': '63.33',
#      'market_value': '316',
#      'qty': '5',
#      'side': 'long',
#      'symbol': 'HES',
#      'unrealized_intraday_pl': '-0.65',
#      'unrealized_intraday_plpc': '-0.0020527396178746',
#      'unrealized_pl': '24.2',
#      'unrealized_plpc': '0.0829335161069225'}),
#  Position({   'asset_class': 'us_equity',
#      'asset_id': 'b6b1ea06-5d71-4146-be77-03f671788940',
#      'avg_entry_price': '182.74',
#      'change_today': '0.0064166833767796',
#      'cost_basis': '913.7',
#      'current_price': '200.76',
#      'exchange': 'NYSE',
#      'lastday_price': '199.48',
#      'market_value': '1003.8',
#      'qty': '5',
#      'side': 'long',
#      'symbol': 'HD',
#      'unrealized_intraday_pl': '6.4',
#      'unrealized_intraday_plpc': '0.0064166833767796',
#      'unrealized_pl': '90.1',
#      'unrealized_plpc': '0.0986100470613987'}),
#  Position({   'asset_class': 'us_equity',
#      'asset_id': '1ce97178-60a2-4bde-93e3-cf93923bd880',
#      'avg_entry_price': '18.51',
#      'change_today': '0.0183231538034425',
#      'cost_basis': '92.55',
#      'current_price': '18.34',
#      'exchange': 'NYSE',
#      'lastday_price': '18.01',
#      'market_value': '91.7',
#      'qty': '5',
#      'side': 'long',
#      'symbol': 'HBI',
#      'unrealized_intraday_pl': '1.65',
#      'unrealized_intraday_plpc': '0.0183231538034425',
#      'unrealized_pl': '-0.85',
#      'unrealized_plpc': '-0.009184224743382'}),
#  Position({   'asset_class': 'us_equity',
#      'asset_id': '064dd45f-7a58-452c-93f2-377f9a0cc7f2',
#      'avg_entry_price': '195.28',
#      'change_today': '0.0015272440634545',
#      'cost_basis': '976.4',
#      'current_price': '203.29',
#      'exchange': 'NYSE',
#      'lastday_price': '202.98',
#      'market_value': '1016.45',
#      'qty': '5',
#      'side': 'long',
#      'symbol': 'GS',
#      'unrealized_intraday_pl': '1.55',
#      'unrealized_intraday_plpc': '0.0015272440634545',
#      'unrealized_pl': '40.05',
#      'unrealized_plpc': '0.0410180253994265'}),
#  Position({   'asset_class': 'us_equity',
#      'asset_id': '2ae65e45-78f1-448b-b33d-08220c03f317',
#      'avg_entry_price': '130.04',
#      'change_today': '-0.0013859508352177',
#      'cost_basis': '650.2',
#      'current_price': '136.9',
#      'exchange': 'NYSE',
#      'lastday_price': '137.09',
#      'market_value': '684.5',
#      'qty': '5',
#      'side': 'long',
#      'symbol': 'GPN',
#      'unrealized_intraday_pl': '-0.95',
#      'unrealized_intraday_plpc': '-0.0013859508352177',
#      'unrealized_pl': '34.3',
#      'unrealized_plpc': '0.052752999077207'}),
#  Position({   'asset_class': 'us_equity',
#      'asset_id': '69b15845-7c63-4586-b274-1cfdfe9df3d8',
#      'avg_entry_price': '1144.38',
#      'change_today': '0.0012018732645364',
#      'cost_basis': '5721.9',
#      'current_price': '1207.9',
#      'exchange': 'NASDAQ',
#      'lastday_price': '1206.45',
#      'market_value': '6039.5',
#      'qty': '5',
#      'side': 'long',
#      'symbol': 'GOOGL',
#      'unrealized_intraday_pl': '7.25',
#      'unrealized_intraday_plpc': '0.0012018732645364',
#      'unrealized_pl': '317.6',
#      'unrealized_plpc': '0.055506038204093'}),
#  Position({   'asset_class': 'us_equity',
#      'asset_id': 'de5fc535-1cdd-4a57-92ba-ac58a43aed81',
#      'avg_entry_price': '39.23',
#      'change_today': '0',
#      'cost_basis': '196.15',
#      'current_price': '39.26',
#      'exchange': 'NYSE',
#      'lastday_price': '39.26',
#      'market_value': '196.3',
#      'qty': '5',
#      'side': 'long',
#      'symbol': 'GM',
# ...
#      'cost_basis': '289.85',
#      'current_price': '58.49',
#      'exchange': 'NYSE',
#      'lastday_price': '58.25',
#      'market_value': '292.45',
#      'qty': '5',
#      'side': 'long',
#      'symbol': 'BLL',
#      'unrealized_intraday_pl': '1.2',
#      'unrealized_intraday_plpc': '0.0041201716738197',
#      'unrealized_pl': '2.6',
#      'unrealized_plpc': '0.0089701569777471'}),
#  Position({   'asset_class': 'us_equity',
#      'asset_id': 'c50070cd-18b4-4f29-ae0f-f192e4cc4553',
#      'avg_entry_price': '1697.15',
#      'change_today': '0.0041290294013461',
#      'cost_basis': '8485.75',
#      'current_price': '1814.18',
#      'exchange': 'NASDAQ',
#      'lastday_price': '1806.72',
#      'market_value': '9070.9',
#      'qty': '5',
#      'side': 'long',
#      'symbol': 'BKNG',
#      'unrealized_intraday_pl': '37.3',
#      'unrealized_intraday_plpc': '0.0041290294013461',
#      'unrealized_pl': '585.15',
#      'unrealized_plpc': '0.0689567804849306'}),
#  Position({   'asset_class': 'us_equity',
#      'asset_id': 'a7416318-2773-49b9-b843-7017e0711a5b',
#      'avg_entry_price': '52.97',
#      'change_today': '-0.0007545746085644',
#      'cost_basis': '264.85',
#      'current_price': '52.97',
#      'exchange': 'NYSE',
#      'lastday_price': '53.01',
#      'market_value': '264.85',
#      'qty': '5',
#      'side': 'long',
#      'symbol': 'BF.B',
#      'unrealized_intraday_pl': '-0.2',
#      'unrealized_intraday_plpc': '-0.0007545746085644',
#      'unrealized_pl': '0',
#      'unrealized_plpc': '0'}),
#  Position({   'asset_class': 'us_equity',
#      'asset_id': 'feee4056-913c-46be-8e7e-71ee600bfe18',
#      'avg_entry_price': '75.03',
#      'change_today': '-0.0078573210276877',
#      'cost_basis': '375.15',
#      'current_price': '79.55',
#      'exchange': 'NYSE',
#      'lastday_price': '80.18',
#      'market_value': '397.75',
#      'qty': '5',
#      'side': 'long',
#      'symbol': 'BAX',
#      'unrealized_intraday_pl': '-3.15',
#      'unrealized_intraday_plpc': '-0.0078573210276877',
#      'unrealized_pl': '22.6',
#      'unrealized_plpc': '0.0602425696388111'}),
#  Position({   'asset_class': 'us_equity',
#      'asset_id': '061588a3-d70b-4b9c-a3f6-636aaa16acc4',
#      'avg_entry_price': '28.94',
#      'change_today': '0.0020632737276479',
#      'cost_basis': '144.7',
#      'current_price': '29.14',
#      'exchange': 'NYSE',
#      'lastday_price': '29.08',
#      'market_value': '145.7',
#      'qty': '5',
#      'side': 'long',
#      'symbol': 'BAC',
#      'unrealized_intraday_pl': '0.3',
#      'unrealized_intraday_plpc': '0.0020632737276479',
#      'unrealized_pl': '1',
#      'unrealized_plpc': '0.0069108500345543'}),
#  Position({   'asset_class': 'us_equity',
#      'asset_id': '3bed4fb2-4093-4433-b887-770ae3defd3a',
#      'avg_entry_price': '430.18',
#      'change_today': '0.0061369863013699',
#      'cost_basis': '2150.9',
#      'current_price': '367.24',
#      'exchange': 'NYSE',
#      'lastday_price': '365',
#      'market_value': '1836.2',
#      'qty': '5',
#      'side': 'long',
#      'symbol': 'BA',
#      'unrealized_intraday_pl': '11.2',
#      'unrealized_intraday_plpc': '0.0061369863013699',
#      'unrealized_pl': '-314.7',
#      'unrealized_plpc': '-0.1463108466223441'}),
#  Position({   'asset_class': 'us_equity',
#      'asset_id': '49b90cdc-f6f5-4a7c-807a-ed172e6017af',
#      'avg_entry_price': '108.41',
#      'change_today': '-0.0033584460379414',
#      'cost_basis': '542.05',
#      'current_price': '109.8',
#      'exchange': 'NYSE',
#      'lastday_price': '110.17',
#      'market_value': '549',
#      'qty': '5',
#      'side': 'long',
#      'symbol': 'AXP',
#      'unrealized_intraday_pl': '-1.85',
#      'unrealized_intraday_plpc': '-0.0033584460379414',
#      'unrealized_pl': '6.95',
#      'unrealized_plpc': '0.0128216954155521'}),
#  Position({   'asset_class': 'us_equity',
#      'asset_id': '6e7afb17-d4ff-499e-9c9d-ddc853786501',
#      'avg_entry_price': '201.12',
#      'change_today': '0.0023243163048316',
#      'cost_basis': '1005.6',
#      'current_price': '202.68',
#      'exchange': 'NYSE',
#      'lastday_price': '202.21',
#      'market_value': '1013.4',
#      'qty': '5',
#      'side': 'long',
#      'symbol': 'AVB',
#      'unrealized_intraday_pl': '2.35',
#      'unrealized_intraday_plpc': '0.0023243163048316',
#      'unrealized_pl': '7.8',
#      'unrealized_plpc': '0.0077565632458234'}),
#  Position({   'asset_class': 'us_equity',
#      'asset_id': '5a7450bd-6796-4631-845e-d3facc79ff1a',
#      'avg_entry_price': '143.7',
#      'change_today': '-0.0007648981294764',
#      'cost_basis': '718.5',
#      'current_price': '143.7',
#      'exchange': 'NYSE',
#      'lastday_price': '143.81',
#      'market_value': '718.5',
#      'qty': '5',
#      'side': 'long',
#      'symbol': 'ARE',
#      'unrealized_intraday_pl': '-0.55',
#      'unrealized_intraday_plpc': '-0.0007648981294764',
#      'unrealized_pl': '0',
#      'unrealized_plpc': '0'}),
#  Position({   'asset_class': 'us_equity',
#      'asset_id': '24eb52f8-21d5-4f0d-8950-79421394163a',
#      'avg_entry_price': '43.97',
#      'change_today': '-0.0023504273504274',
#      'cost_basis': '219.85',
#      'current_price': '46.69',
#      'exchange': 'NYSE',
#      'lastday_price': '46.8',
#      'market_value': '233.45',
#      'qty': '5',
#      'side': 'long',
#      'symbol': 'APC',
#      'unrealized_intraday_pl': '-0.55',
#      'unrealized_intraday_plpc': '-0.0023504273504274',
#      'unrealized_pl': '13.6',
#      'unrealized_plpc': '0.0618603593359108'}),
#  Position({   'asset_class': 'us_equity',
#      'asset_id': '267f9ea7-eb9a-41cd-946f-5fab57943f0a',
#      'avg_entry_price': '291.28',
#      'change_today': '-0.0393919411376809',
#      'cost_basis': '1456.4',
#      'current_price': '276.78',
#      'exchange': 'NYSE',
#      'lastday_price': '288.13',
#      'market_value': '1383.9',
#      'qty': '5',
#      'side': 'long',
#      'symbol': 'ANTM',
#      'unrealized_intraday_pl': '-56.75',
#      'unrealized_intraday_plpc': '-0.0393919411376809',
#      'unrealized_pl': '-72.5',
#      'unrealized_plpc': '-0.0497802801428179'}),
#  Position({   'asset_class': 'us_equity',
#      'asset_id': 'cbfae067-8c09-47a5-86f1-276f2ece42e9',
#      'avg_entry_price': '283.47',
#      'change_today': '0.0002791736460078',
#      'cost_basis': '1417.35',
#      'current_price': '322.47',
#      'exchange': 'NYSE',
#      'lastday_price': '322.38',
#      'market_value': '1612.35',
#      'qty': '5',
#      'side': 'long',
#      'symbol': 'ANET',
#      'unrealized_intraday_pl': '0.45',
#      'unrealized_intraday_plpc': '0.0002791736460078',
#      'unrealized_pl': '195',
#      'unrealized_plpc': '0.1375806963699862'}),
#  Position({   'asset_class': 'us_equity',
#      'asset_id': 'f801f835-bfe6-4a9d-a6b1-ccbb84bfd75f',
#      'avg_entry_price': '1693.12',
#      'change_today': '-0.0017917751565773',
#      'cost_basis': '8465.6',
#      'current_price': '1844.02',
#      'exchange': 'NASDAQ',
#      'lastday_price': '1847.33',
#      'market_value': '9220.1',
#      'qty': '5',
#      'side': 'long',
#      'symbol': 'AMZN',
#      'unrealized_intraday_pl': '-16.55',
#      'unrealized_intraday_plpc': '-0.0017917751565773',
#      'unrealized_pl': '754.5',
#      'unrealized_plpc': '0.0891254016254016'}),
#  Position({   'asset_class': 'us_equity',
#      'asset_id': 'a148da60-6af9-443b-a3a9-9d3e65eb91e9',
#      'avg_entry_price': '194.81',
#      'change_today': '-0.0034075882412776',
#      'cost_basis': '974.05',
#      'current_price': '195.95',
#      'exchange': 'NYSE',
#      'lastday_price': '196.62',
#      'market_value': '979.75',
#      'qty': '5',
#      'side': 'long',
#      'symbol': 'AMT',
#      'unrealized_intraday_pl': '-3.35',
#      'unrealized_intraday_plpc': '-0.0034075882412776',
#      'unrealized_pl': '5.7',
#      'unrealized_plpc': '0.0058518556542272'}),
#  Position({   'asset_class': 'us_equity',
#      'asset_id': '201b268b-cde8-4010-9fe3-41d2ac7f1e9c',
#      'avg_entry_price': '188.28',
#      'change_today': '-0.0112950642116664',
#      'cost_basis': '941.4',
#      'current_price': '191.7',
#      'exchange': 'NASDAQ',
#      'lastday_price': '193.89',
#      'market_value': '958.5',
#      'qty': '5',
#      'side': 'long',
#      'symbol': 'AMGN',
#      'unrealized_intraday_pl': '-10.95',
#      'unrealized_intraday_plpc': '-0.0112950642116664',
#      'unrealized_pl': '17.1',
#      'unrealized_plpc': '0.0181644359464627'}),
#  Position({   'asset_class': 'us_equity',
#      'asset_id': '03fb07bb-5db1-4077-8dea-5d711b272625',
#      'avg_entry_price': '23.3',
#      'change_today': '-0.0032339202299677',
#      'cost_basis': '116.5',
#      'current_price': '27.74',
#      'exchange': 'NASDAQ',
#      'lastday_price': '27.83',
#      'market_value': '138.7',
#      'qty': '5',
#      'side': 'long',
#      'symbol': 'AMD',
#      'unrealized_intraday_pl': '-0.45',
#      'unrealized_intraday_plpc': '-0.0032339202299677',
#      'unrealized_pl': '22.2',
#      'unrealized_plpc': '0.1905579399141631'}),
#  Position({   'asset_class': 'us_equity',
#      'asset_id': '1855127e-54da-4909-929a-83c316ba4b89',
#      'avg_entry_price': '139.56',
#      'change_today': '-0.0266827093212542',
#      'cost_basis': '697.8',
#      'current_price': '137.52',
#      'exchange': 'NASDAQ',
#      'lastday_price': '141.29',
#      'market_value': '687.6',
#      'qty': '5',
#      'side': 'long',
#      'symbol': 'ALXN',
#      'unrealized_intraday_pl': '-18.85',
#      'unrealized_intraday_plpc': '-0.0266827093212542',
#      'unrealized_pl': '-10.2',
#      'unrealized_plpc': '-0.0146173688736028'}),
#  Position({   'asset_class': 'us_equity',
#      'asset_id': '706a4e67-10db-4ca5-9d05-5163302d734d',
#      'avg_entry_price': '59.52',
#      'change_today': '0.0141204491323579',
#      'cost_basis': '297.6',
#      'current_price': '59.61',
#      'exchange': 'NYSE',
#      'lastday_price': '58.78',
#      'market_value': '298.05',
#      'qty': '5',
#      'side': 'long',
#      'symbol': 'ALK',
#      'unrealized_intraday_pl': '4.15',
#      'unrealized_intraday_plpc': '0.0141204491323579',
#      'unrealized_pl': '0.45',
#      'unrealized_plpc': '0.0015120967741935'}),
#  Position({   'asset_class': 'us_equity',
#      'asset_id': '6a5d1d05-d652-48a6-b33f-98991c0a442a',
#      'avg_entry_price': '49.04',
#      'change_today': '-0.0025575447570332',
#      'cost_basis': '245.2',
#      'current_price': '50.7',
#      'exchange': 'NYSE',
#      'lastday_price': '50.83',
#      'market_value': '253.5',
#      'qty': '5',
#      'side': 'long',
#      'symbol': 'AIV',
#      'unrealized_intraday_pl': '-0.65',
#      'unrealized_intraday_plpc': '-0.0025575447570332',
#      'unrealized_pl': '8.3',
#      'unrealized_plpc': '0.0338499184339315'}),
#  Position({   'asset_class': 'us_equity',
#      'asset_id': '13488509-3dd7-4e28-9ede-1531dc353354',
#      'avg_entry_price': '16.98',
#      'change_today': '-0.0016611295681063',
#      'cost_basis': '84.9',
#      'current_price': '18.03',
#      'exchange': 'NYSE',
#      'lastday_price': '18.06',
#      'market_value': '90.15',
#      'qty': '5',
#      'side': 'long',
#      'symbol': 'AES',
#      'unrealized_intraday_pl': '-0.15',
#      'unrealized_intraday_plpc': '-0.0016611295681063',
#      'unrealized_pl': '5.25',
#      'unrealized_plpc': '0.0618374558303887'}),
#  Position({   'asset_class': 'us_equity',
#      'asset_id': '98ce4784-3b9a-4a4f-88ec-f2db2f1e8961',
#      'avg_entry_price': '71.61',
#      'change_today': '0.0011187246538946',
#      'cost_basis': '358.05',
#      'current_price': '71.59',
#      'exchange': 'NYSE',
#      'lastday_price': '71.51',
#      'market_value': '357.95',
#      'qty': '5',
#      'side': 'long',
#      'symbol': 'AEE',
#      'unrealized_intraday_pl': '0.4',
#      'unrealized_intraday_plpc': '0.0011187246538946',
#      'unrealized_pl': '-0.1',
#      'unrealized_plpc': '-0.0002792906018712'}),
#  Position({   'asset_class': 'us_equity',
#      'asset_id': 'a21ecb08-ff55-4c19-94d3-a8d607d91be8',
#      'avg_entry_price': '156.22',
#      'change_today': '0.0066889632107023',
#      'cost_basis': '781.1',
#      'current_price': '171.57',
#      'exchange': 'NASDAQ',
#      'lastday_price': '170.43',
#      'market_value': '857.85',
#      'qty': '5',
#      'side': 'long',
#      'symbol': 'ADSK',
#      'unrealized_intraday_pl': '5.7',
#      'unrealized_intraday_plpc': '0.0066889632107023',
#      'unrealized_pl': '76.75',
#      'unrealized_plpc': '0.0982588657022148'}),
#  Position({   'asset_class': 'us_equity',
#      'asset_id': '6ca2e51d-21df-4ff0-a134-abfdbe084142',
#      'avg_entry_price': '152.3',
#      'change_today': '0.0054219120029914',
#      'cost_basis': '761.5',
#      'current_price': '161.33',
#      'exchange': 'NASDAQ',
#      'lastday_price': '160.46',
#      'market_value': '806.65',
#      'qty': '5',
#      'side': 'long',
#      'symbol': 'ADP',
#      'unrealized_intraday_pl': '4.35',
#      'unrealized_intraday_plpc': '0.0054219120029914',
#      'unrealized_pl': '45.15',
#      'unrealized_plpc': '0.0592908732764281'}),
#  Position({   'asset_class': 'us_equity',
#      'asset_id': '41e7c72d-bf5f-4ff9-9813-387ef5038cf3',
#      'avg_entry_price': '41.95',
#      'change_today': '-0.0016181229773463',
#      'cost_basis': '209.75',
#      'current_price': '43.19',
#      'exchange': 'NYSE',
#      'lastday_price': '43.26',
#      'market_value': '215.95',
#      'qty': '5',
#      'side': 'long',
#      'symbol': 'ADM',
#      'unrealized_intraday_pl': '-0.35',
#      'unrealized_intraday_plpc': '-0.0016181229773463',
#      'unrealized_pl': '6.2',
#      'unrealized_plpc': '0.0295589988081049'}),
#  Position({   'asset_class': 'us_equity',
#      'asset_id': 'e72fbd29-be6b-43c2-80c6-b6e80d5b23db',
#      'avg_entry_price': '107.618',
#      'change_today': '-0.0024087786600054',
#      'cost_basis': '538.09',
#      'current_price': '111.82',
#      'exchange': 'NASDAQ',
#      'lastday_price': '112.09',
#      'market_value': '559.1',
#      'qty': '5',
#      'side': 'long',
#      'symbol': 'ADI',
#      'unrealized_intraday_pl': '-1.35',
#      'unrealized_intraday_plpc': '-0.0024087786600054',
#      'unrealized_pl': '21.01',
#      'unrealized_plpc': '0.0390455128324258'}),
#  Position({   'asset_class': 'us_equity',
#      'asset_id': '2ac633b5-b3a7-4ba6-975d-f0f1e12dd1e4',
#      'avg_entry_price': '256.25',
#      'change_today': '0.0000368229185845',
#      'cost_basis': '1281.25',
#      'current_price': '271.58',
#      'exchange': 'NASDAQ',
#      'lastday_price': '271.57',
#      'market_value': '1357.9',
#      'qty': '5',
#      'side': 'long',
#      'symbol': 'ADBE',
#      'unrealized_intraday_pl': '0.05',
#      'unrealized_intraday_plpc': '0.0000368229185845',
#      'unrealized_pl': '76.65',
#      'unrealized_plpc': '0.0598243902439024'}),
#  Position({   'asset_class': 'us_equity',
#      'asset_id': '6eace613-5882-4eca-8635-d1c41ee9e260',
#      'avg_entry_price': '161.59',
#      'change_today': '0.0052539404553415',
#      'cost_basis': '807.95',
#      'current_price': '177.94',
#      'exchange': 'NYSE',
#      'lastday_price': '177.01',
#      'market_value': '889.7',
#      'qty': '5',
#      'side': 'long',
#      'symbol': 'ACN',
#      'unrealized_intraday_pl': '4.65',
#      'unrealized_intraday_plpc': '0.0052539404553415',
#      'unrealized_pl': '81.75',
#      'unrealized_plpc': '0.1011820038368711'}),
#  Position({   'asset_class': 'us_equity',
#      'asset_id': 'b0b6dd9d-8b9b-48a9-ba46-b9d54906e415',
#      'avg_entry_price': '175.11',
#      'change_today': '-0.0078740157480315',
#      'cost_basis': '875.55',
#      'current_price': '199.08',
#      'exchange': 'NASDAQ',
#      'lastday_price': '200.66',
#      'market_value': '995.4',
#      'qty': '5',
#      'side': 'long',
#      'symbol': 'AAPL',
#      'unrealized_intraday_pl': '-7.9',
#      'unrealized_intraday_plpc': '-0.0078740157480315',
#      'unrealized_pl': '119.85',
#      'unrealized_plpc': '0.1368853863285935'}),
#  Position({   'asset_class': 'us_equity',
#      'asset_id': '7595a8d2-68a6-46d7-910c-6b1958491f5c',
#      'avg_entry_price': '79.97',
#      'change_today': '-0.0085689802913453',
#      'cost_basis': '399.85',
#      'current_price': '80.99',
#      'exchange': 'NYSE',
#      'lastday_price': '81.69',
#      'market_value': '404.95',
#      'qty': '5',
#      'side': 'long',
#      'symbol': 'A',
#      'unrealized_intraday_pl': '-3.5',
#      'unrealized_intraday_plpc': '-0.0085689802913453',
#      'unrealized_pl': '5.1',
#      'unrealized_plpc': '0.0127547830436414'})]

# %%
response = requests.get('https://api.polygon.io/v1/historic/agg/minute/AAPL?apiKey=PKQ696NV2EWC8UJT6MWW')
print(response.content)
# Out:
# b'{"symbol":"AAPL","aggType":"min","map":{"o":"open","c":"close","h":"high","l":"low","v":"volume","t":"timestamp","d":"timestamp"},"ticks":[{"o":196.95,"c":196.9,"h":196.98,"l":196.9,"v":2112,"t":1554508740000,"d":1554508740000},{"o":196.99,"c":196.99,"h":196.99,"l":196.99,"v":130,"t":1554508680000,"d":1554508680000},{"o":196.9,"c":196.9,"h":196.9,"l":196.9,"v":700,"t":1554508560000,"d":1554508560000},{"o":196.96,"c":196.96,"h":196.96,"l":196.96,"v":160,"t":1554508440000,"d":1554508440000},{"o":196.96,"c":196.96,"h":196.96,"l":196.96,"v":150,"t":1554508380000,"d":1554508380000},{"o":196.96,"c":196.96,"h":196.96,"l":196.96,"v":120,"t":1554508320000,"d":1554508320000},{"o":196.95,"c":196.95,"h":196.95,"l":196.95,"v":190,"t":1554508260000,"d":1554508260000},{"o":196.96,"c":196.96,"h":196.96,"l":196.96,"v":140,"t":1554508200000,"d":1554508200000},{"o":196.96,"c":196.95,"h":196.96,"l":196.95,"v":290,"t":1554508140000,"d":1554508140000},{"o":196.96,"c":196.96,"h":196.96,"l":196.96,"v":1297,"t":1554508080000,"d":1554508080000},{"o":196.95,"c":197,"h":197,"l":196.95,"v":692,"t":1554508020000,"d":1554508020000},{"o":196.95,"c":196.95,"h":196.95,"l":196.95,"v":200,"t":1554507960000,"d":1554507960000},{"o":196.89,"c":196.93,"h":196.93,"l":196.89,"v":2714,"t":1554507540000,"d":1554507540000},{"o":196.95,"c":196.92,"h":196.95,"l":196.92,"v":1352,"t":1554506880000,"d":1554506880000},{"o":196.95,"c":196.95,"h":196.95,"l":196.95,"v":800,"t":1554506820000,"d":1554506820000},{"o":196.92,"c":196.92,"h":196.92,"l":196.92,"v":118,"t":1554506520000,"d":1554506520000},{"o":196.9,"c":196.9,"h":196.9,"l":196.9,"v":200,"t":1554506340000,"d":1554506340000},{"o":196.94,"c":196.94,"h":196.94,"l":196.94,"v":305,"t":1554505980000,"d":1554505980000},{"o":196.94,"c":196.94,"h":196.94,"l":196.94,"v":100,"t":1554505740000,"d":1554505740000},{"o":196.92,"c":196.92,"h":196.92,"l":196.92,"v":209,"t":1554505440000,"d":1554505440000},{"o":196.99,"c":196.99,"h":196.99,"l":196.99,"v":182,"t":1554504480000,"d":1554504480000},{"o":196.92,"c":196.92,"h":196.92,"l":196.92,"v":5000,"t":1554504180000,"d":1554504180000},{"o":196.95,"c":196.95,"h":196.95,"l":196.95,"v":927,"t":1554504060000,"d":1554504060000},{"o":197,"c":197,"h":197,"l":197,"v":300,"t":1554503580000,"d":1554503580000},{"o":197,"c":197,"h":197,"l":197,"v":100,"t":1554502800000,"d":1554502800000},{"o":196.95,"c":196.95,"h":196.95,"l":196.95,"v":225,"t":1554502500000,"d":1554502500000},{"o":197,"c":197,"h":197,"l":197,"v":600,"t":1554502140000,"d":1554502140000},{"o":197,"c":197,"h":197,"l":197,"v":200,"t":1554501960000,"d":1554501960000},{"o":196.95,"c":196.95,"h":196.95,"l":196.95,"v":3681,"t":1554501600000,"d":1554501600000},{"o":196.95,"c":196.95,"h":196.95,"l":196.95,"v":1004,"t":1554501540000,"d":1554501540000},{"o":196.95,"c":196.95,"h":196.95,"l":196.95,"v":1200,"t":1554501480000,"d":1554501480000},{"o":196.97,"c":196.97,"h":196.97,"l":196.97,"v":102,"t":1554501180000,"d":1554501180000},{"o":196.94,"c":196.94,"h":196.94,"l":196.94,"v":702,"t":1554501120000,"d":1554501120000},{"o":197,"c":197,"h":197,"l":197,"v":827,"t":1554501000000,"d":1554501000000},{"o":196.93,"c":196.99,"h":196.99,"l":196.93,"v":400,"t":1554500940000,"d":1554500940000},{"o":196.96,"c":196.93,"h":196.96,"l":196.93,"v":4563,"t":1554500880000,"d":1554500880000},{"o":196.95,"c":196.96,"h":196.96,"l":196.95,"v":1449,"t":1554500640000,"d":1554500640000},{"o":196.95,"c":196.95,"h":196.95,"l":196.95,"v":864,"t":1554500580000,"d":1554500580000},{"o":196.94,"c":196.95,"h":196.95,"l":196.94,"v":501,"t":1554500520000,"d":1554500520000},{"o":196.92,"c":196.92,"h":196.92,"l":196.92,"v":211,"t":1554500460000,"d":1554500460000},{"o":196.92,"c":196.92,"h":196.92,"l":196.92,"v":132,"t":1554500340000,"d":1554500340000},{"o":196.92,"c":196.92,"h":196.92,"l":196.92,"v":100,"t":1554500100000,"d":1554500100000},{"o":196.92,"c":196.92,"h":196.92,"l":196.92,"v":750,"t":1554499260000,"d":1554499260000},{"o":196.92,"c":196.92,"h":196.92,"l":196.92,"v":140,"t ...

# %%
# all-in-one SVC predictor on entirety of SP500

start = time.time()

accuracy_results = {}
returns = {}

for ticker in sp500:
    try:
        loop_start = time.time()
        #download current ticker data
        print(" ")
        print("********************************")
        print(ticker, " starting: ")
        Df = web.DataReader(ticker, 'iex', start="2014-01-01", end="2019-03-01")
        Df = Df.dropna()
        #print(Df.head())
        #Df.close.plot(figsize=(15,10))
        #plt.ylabel("AAPL Price")
        #plt.show()

        # create new "X" dataframe containing features
        Df['open-close'] = Df.open - Df.close
        Df['high-low'] = Df.high - Df.low
        #Df['change'] = Df['close'].pct_change().shift(-1) # recalculates change

        Df = ss.StockDataFrame.retype(Df) #coerces df into StockDataFrame
        Df['macd'] # calculate MACD indicator for the entire "btc" df and automatically appends to new column
        Df["rsi_6"]
        Df['volume_delta']
        Df['open_-1_r']
        Df['cr']
        Df['cr-ma1']
        Df['cr-ma2']
        Df['cr-ma3']
        Df["rsi_12"]
        Df["wr_10"]
        Df["cci"]
        Df['tr']
        Df['atr']
        Df['dma']
        Df['pdi']
        Df['mdi']
        Df['dx']
        Df['adx']
        Df['adxr']
        Df['trix']
        Df['trix_9_sma']
        Df['vr']
        Df = pd.DataFrame(Df)
        Df = Df.dropna()
        #X_temp = Df[['close','open-close','high-low']].iloc[2:,:]
        #X_temp = Df[['close','open-close','high-low', 'rs_6', 'rsi_6', 'macd', 'macds','macdh']].iloc[2:,:]
        X_temp = Df[['close','open-close','high-low', 'rs_6', 'rsi_6', 'macd', 'macds','macdh','close_26_ema','volume_delta','open_-1_r','middle','cr','cr-ma1','cr-ma2','cr-ma3','close_-1_s','close_-1_d','rs_6','rsi_6','rs_12','rsi_12','wr_10','middle_14_sma','cci','tr','atr','close_10_sma','close_50_sma','dma','high_delta','um','low_delta','dm','pdm','pdm_14_ema','pdm_14','atr_14','pdi_14','pdi','mdm','mdm_14_ema','mdm_14','mdi_14','mdi','dx_14','dx','dx_6_ema','adx','adx_6_ema','adxr','trix','trix_9_sma','vr']].iloc[2:,:]
        X_temp = X_temp.dropna()
                
        # create numpy array containing +1/-1 depending on yesterday's price change
        y = np.where(X_temp['close'].shift(-1) > X_temp['close'],1,-1)
        X = X_temp.drop(columns='close')
        
        # split data into training / test
        split_percentage = 0.8
        split = int(split_percentage*len(Df))
        #print("Split: ", split)
        # Train data set
        X_train = X[:split].values
        y_train = y[:split]
        # Test data set
        X_test = X[split:].values
        y_test = y[split:]
        #print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
        #print(y_test)

        # train
        sc = StandardScaler()
        X_train = sc.fit_transform(X_train)
        X_test = sc.transform(X_test)
        cls = SVC().fit(X_train, y_train)

        # accuracies
        accuracy_train = accuracy_score(y_train, cls.predict(X_train))
        accuracy_test = accuracy_score(y_test, cls.predict(X_test))
        print(ticker, "results:")
        print('Train Accuracy:{: .2f}%'.format(accuracy_train*100))
        print('Test Accuracy:{: .2f}%'.format(accuracy_test*100))
        # append to accuracy_results dict
        accuracy_results[ticker] = (accuracy_train*100, accuracy_test*100)
        
        predicted_signal = cls.predict(X_test)
        return_ = np.log(X_temp[split:].close.shift(-1) / X_temp[split:].close)*100 #X_temp[split:] == X_test
        #return_ = (X_temp[split:].close.shift(-1) / X_temp[split:].close)*100 #X_temp[split:] == X_test
        strategy_return = return_ * predicted_signal
        #print("Return difference: ", strategy_return[split:].cumsum()[len(strategy_return)-2] - return_[split:].cumsum()[len(return_)-2])
        print("Return difference: ", strategy_return.cumsum()[len(strategy_return)-2] - return_.cumsum()[len(return_)-2])
        returns[ticker] = [accuracy_train*100, accuracy_test*100, return_.cumsum().iloc[-2], strategy_return.cumsum().iloc[-2]]
        
        loop_end = time.time()
        print("Loop run-time: ", (loop_end - loop_start))
        
        '''
        # calculate returns during testing only
        Df['Predicted_Signal'] = cls.predict(X)
        # Calculate log returns
        Df['Return'] = np.log(Df.close.shift(-1) / Df.close)*100
        Df['Strategy_Return'] = Df.Return * Df.Predicted_Signal
        print("Return difference: ", Df.Strategy_Return.iloc[split:].cumsum().iloc[-2]-Df.Return.iloc[split:].cumsum().iloc[-2])
        returns[ticker] = [Df.Return.iloc[split:].cumsum().iloc[-2], Df.Strategy_Return.iloc[split:].cumsum().iloc[-2]]
        '''
    except Exception as e: 
        print("ERROR: ", e)
        print(ticker, "FAILED!!!")
        accuracy_results[ticker] = (0,0)
        returns[ticker] = [0,0,0,0]
        loop_end = time.time()
        print("Loop run-time: ", (loop_end - loop_start))
        
end = time.time()
print("Script run-time: ", (end - start))
        
df_returns = pd.DataFrame.from_dict(returns, columns=['Train Accuracy','Test Accuracy','Hold Return', 'Strategy Return'], orient='index')
df_returns.to_csv("stockstats_testing_returns.csv")

winsound.Beep(1000,1000)
# Out:
#
# ********************************
# A  starting:
# c:\python36\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# c:\python36\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
# c:\python36\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# A results:
# Train Accuracy: 65.85%
# Test Accuracy: 50.82%
# Return difference:  -0.5247484323326965
# Loop run-time:  2.1949987411499023
#
# ********************************
# AAL  starting:
# c:\python36\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# c:\python36\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
# c:\python36\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# AAL results:
# Train Accuracy: 68.71%
# Test Accuracy: 54.10%
# Return difference:  103.54108993597708
# Loop run-time:  2.1448159217834473
#
# ********************************
# AAP  starting:
# c:\python36\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# c:\python36\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
# c:\python36\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# AAP results:
# Train Accuracy: 66.77%
# Test Accuracy: 49.59%
# Return difference:  8.9143705848116
# Loop run-time:  1.9506733417510986
#
# ********************************
# AAPL  starting:
# c:\python36\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# c:\python36\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
# c:\python36\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# AAPL results:
# Train Accuracy: 64.32%
# Test Accuracy: 49.59%
# Return difference:  -13.95607543017849
# Loop run-time:  1.493511438369751
#
# ********************************
# ABBV  starting:
# c:\python36\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# c:\python36\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
# c:\python36\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# ABBV results:
# Train Accuracy: 62.24%
# Test Accuracy: 50.82%
# Return difference:  8.038954068952116
# Loop run-time:  1.6370294094085693
#
# ********************************
# ABC  starting:
# c:\python36\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# c:\python36\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
# c:\python36\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# ABC results:
# Train Accuracy: 65.55%
# Test Accuracy: 48.36%
# Return difference:  -10.105298465209462
# Loop run-time:  1.9459996223449707
#
# ********************************
# ABMD  starting:
# c:\python36\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# c:\python36\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
# c:\python36\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# ABMD results:
# Train Accuracy: 63.40%
# Test Accuracy: 54.51%
# Return difference:  11.672646418507593
# Loop run-time:  1.5382511615753174
#
# ********************************
# ABT  starting:
# c:\python36\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# c:\python36\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
# c:\python36\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# ABT results:
# Train Accuracy: 66.67%
# Test Accuracy: 57.38%
# Return difference:  5.667811817680359
# Loop run-time:  2.063819169998169
#
# ********************************
# ACN  starting:
# c:\python36\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# c:\python36\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
# c:\python36\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# ACN results:
# Train Accuracy: 67.07%
# Test Accuracy: 56.56%
# Return difference:  10.42507891839241
# Loop run-time:  2.06693959236145
#
# ********************************
# ADBE  starting:
# c:\python36\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# c:\python36\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
# c:\python36\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# ADBE results:
# Train Accuracy: 64.02%
# Test Accuracy: 56.15%
# Return difference:  9.640520054447745
# Loop run-time:  2.2949352264404297
#
# ********************************
# ADI  starting:
# c:\python36\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# c:\python36\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
# c:\python36\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# ADI results:
# Train Accuracy: 68.50%
# Test Accuracy: 50.41%
# Return difference:  9.937027247649429
# Loop run-time:  1.9286198616027832
#
# ********************************
# ADM  starting:
# c:\python36\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# c:\python36\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
# c:\python36\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# ADM results:
# Train Accuracy: 65.65%
# Test Accuracy: 53.28%
# Return difference:  25.621725936984014
# Loop run-time:  1.954186201095581
#
# ********************************
# ADP  starting:
# c:\python36\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# c:\python36\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
# c:\python36\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# ADP results:
# Train Accuracy: 65.95%
# Test Accuracy: 45.90%
# Return difference:  -36.10131780853433
# Loop run-time:  2.212197780609131
#
# ********************************
# ADS  starting:
# c:\python36\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# c:\python36\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
# c:\python36\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# ADS results:
# Train Accuracy: 67.48%
# Test Accuracy: 48.36%
# Return difference:  21.289916529653333
# Loop run-time:  2.204697847366333
#
# ********************************
# ADSK  starting:
# c:\python36\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# c:\python36\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
# c:\python36\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# ADSK results:
# Train Accuracy: 64.63%
# Test Accuracy: 48.77%
# Return difference:  -22.566845195255958
# Loop run-time:  1.9083044528961182
#
# ********************************
# AEE  starting:
# c:\python36\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# c:\python36\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
# c:\python36\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# AEE results:
# Train Accuracy: 63.81%
# Test Accuracy: 51.23%
# Return difference:  -13.162238962089308
# Loop run-time:  1.9424386024475098
#
# ********************************
# AEP  starting:
# c:\python36\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# c:\python36\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
# c:\python36\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# AEP results:
# Train Accuracy: 68.50%
# Test Accuracy: 54.10%
# Return difference:  -6.561454050225617
# Loop run-time:  2.07558536529541
#
# ********************************
# AES  starting:
# c:\python36\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# c:\python36\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
# c:\python36\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# AES results:
# Train Accuracy: 68.30%
# Test Accuracy: 47.54%
# Return difference:  -80.60365579119421
# Loop run-time:  1.8748111724853516
#
# ********************************
# AFL  starting:
# c:\python36\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# c:\python36\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
# c:\python36\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# AFL results:
# Train Accuracy: 65.92%
# Test Accuracy: 50.82%
# Return difference:  11.056395047888895
# Loop run-time:  2.166534185409546
#
# ********************************
# AGN  starting:
# c:\python36\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# c:\python36\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
# c:\python36\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# AGN results:
# Train Accuracy: 64.73%
# Test Accuracy: 48.36%
# Return difference:  7.241480280880982
# Loop run-time:  2.0493111610412598
#
# ********************************
# AIG  starting:
# c:\python36\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# c:\python36\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
# c:\python36\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# AIG results:
# Train Accuracy: 68.98%
# Test Accuracy: 52.87%
# Return difference:  21.513559672889237
# Loop run-time:  2.178199052810669
#
# ********************************
# AIV  starting:
# c:\python36\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# c:\python36\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
# c:\python36\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# AIV results:
# Train Accuracy: 67.69%
# Test Accuracy: 56.56%
# Return difference:  20.685970398799675
# Loop run-time:  2.0350687503814697
#
# ********************************
# AIZ  starting:
# c:\python36\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# c:\python36\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
# c:\python36\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# AIZ results:
# Train Accuracy: 67.14%
# Test Accuracy: 48.36%
# Return difference:  -21.236084631970044
# Loop run-time:  1.6548585891723633
#
# ********************************
# AJG  starting:
# c:\python36\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# c:\python36\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
# c:\python36\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# AJG results:
# Train Accuracy: 64.12%
# Test Accuracy: 51.64%
# Return difference:  -15.102182367728568
# Loop run-time:  2.1271674633026123
#
# ********************************
# AKAM  starting:
# c:\python36\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# c:\python36\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
# c:\python36\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# AKAM results:
# Train Accuracy: 64.93%
# Test Accuracy: 53.69%
# Return difference:  31.279066301706912
# Loop run-time:  2.142667293548584
#
# ********************************
# ALB  starting:
# c:\python36\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# c:\python36\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
# c:\python36\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# ALB results:
# Train Accuracy: 63.91%
# Test Accuracy: 52.87%
# Return difference:  10.560906239743307
# Loop run-time:  1.8256769180297852
#
# ********************************
# ALGN  starting:
# c:\python36\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# c:\python36\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
# c:\python36\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# ALGN results:
# Train Accuracy: 62.08%
# Test Accuracy: 54.10%
# Return difference:  -14.99795646773837
# Loop run-time:  1.8292405605316162
#
# ********************************
# ALK  starting:
# c:\python36\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# c:\python36\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
# c:\python36\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# ALK results:
# Train Accuracy: 66.36%
# Test Accuracy: 58.61%
# Return difference:  43.25987651391272
# Loop run-time:  1.4007253646850586
#
# ********************************
# ALL  starting:
# c:\python36\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# c:\python36\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
# c:\python36\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# ALL results:
# Train Accuracy: 68.98%
# Test Accuracy: 52.87%
# Return difference:  -5.309328907739882
# Loop run-time:  2.1932904720306396
#
# ********************************
# ALLE  starting:
# c:\python36\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# c:\python36\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
# c:\python36\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# ALLE results:
# Train Accuracy: 66.12%
# Test Accuracy: 50.41%
# Return difference:  -4.724466929064198
# Loop run-time:  2.039341926574707
#
# ********************************
# ALXN  starting:
# c:\python36\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# c:\python36\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
# c:\python36\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# ALXN results:
# Train Accuracy: 65.34%
# Test Accuracy: 47.13%
# Return difference:  -62.784537039323844
# Loop run-time:  1.8554737567901611
#
# ********************************
# AMAT  starting:
# c:\python36\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# c:\python36\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
# c:\python36\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# AMAT results:
# Train Accuracy: 63.98%
# Test Accuracy: 52.05%
# Return difference:  37.459552541712746
# Loop run-time:  2.153381824493408
#
# ********************************
# AMD  starting:
# c:\python36\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# c:\python36\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
# c:\python36\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# AMD results:
# Train Accuracy: 65.85%
# Test Accuracy: 49.18%
# Return difference:  -111.57952990774922
# Loop run-time:  2.314634323120117
#
# ********************************
# AME  starting:
# c:\python36\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# c:\python36\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
# c:\python36\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# AME results:
# Train Accuracy: 66.26%
# Test Accuracy: 46.31%
# Return difference:  -11.533094560552755
# Loop run-time:  2.2993357181549072
#
# ********************************
# AMG  starting:
# c:\python36\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# c:\python36\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
# c:\python36\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# AMG results:
# Train Accuracy: 67.28%
# Test Accuracy: 47.95%
# Return difference:  37.47380958071608
# Loop run-time:  1.9754650592803955
#
# ********************************
# AMGN  starting:
# c:\python36\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# c:\python36\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
# c:\python36\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# AMGN results:
# Train Accuracy: 65.34%
# Test Accuracy: 50.00%
# Return difference:  20.379759368150367
# Loop run-time:  2.078155994415283
#
# ********************************
# AMP  starting:
# c:\python36\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# c:\python36\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
# c:\python36\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# AMP results:
# Train Accuracy: 65.75%
# Test Accuracy: 52.46%
# Return difference:  38.23831191486857
# Loop run-time:  1.8914988040924072
#
# ********************************
# AMT  starting:
# c:\python36\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# c:\python36\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
# c:\python36\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# AMT results:
# Train Accuracy: 65.65%
# Test Accuracy: 51.64%
# Return difference:  -21.042193694425357
# Loop run-time:  1.3881964683532715
#
# ********************************
# AMZN  starting:
# c:\python36\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# c:\python36\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
# c:\python36\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# AMZN results:
# Train Accuracy: 64.93%
# Test Accuracy: 52.05%
# Return difference:  -23.794901946181046
# Loop run-time:  1.966447353363037
#
# ********************************
# ANET  starting:
# c:\python36\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# c:\python36\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
# c:\python36\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# ANET results:
# Train Accuracy: 62.86%
# Test Accuracy: 52.34%
# Return difference:  -6.971131017135843
# Loop run-time:  2.020017385482788
#
# ********************************
# ANSS  starting:
# c:\python36\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# c:\python36\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
# c:\python36\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# ANSS results:
# Train Accuracy: 64.63%
# Test Accuracy: 52.46%
# Return difference:  7.092050877164468
# Loop run-time:  1.987154245376587
#
# ********************************
# ANTM  starting:
# c:\python36\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# c:\python36\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
# c:\python36\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# ANTM results:
# Train Accuracy: 65.31%
# Test Accuracy: 53.69%
# Return difference:  -18.84962832901941
# Loop run-time:  2.0786983966827393
#
# ********************************
# AON  starting:
# c:\python36\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# c:\python36\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
# c:\python36\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# AON results:
# Train Accuracy: 66.97%
# Test Accuracy: 48.77%
# Return difference:  -35.965784825670944
# Loop run-time:  2.04178786277771
#
# ********************************
# AOS  starting:
# c:\python36\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# c:\python36\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
# c:\python36\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# AOS results:
# Train Accuracy: 64.83%
# Test Accuracy: 49.18%
# Return difference:  11.799995490462504
# Loop run-time:  2.3264970779418945
#
# ********************************
# APA  starting:
# c:\python36\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# c:\python36\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
# c:\python36\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# APA results:
# Train Accuracy: 65.00%
# Test Accuracy: 49.38%
# Return difference:  34.903881543093156
# Loop run-time:  1.8985130786895752
#
# ********************************
# APC  starting:
# c:\python36\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# c:\python36\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
# c:\python36\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# APC results:
# Train Accuracy: 66.97%
# Test Accuracy: 52.05%
# Return difference:  25.878803272828492
# Loop run-time:  1.8865752220153809
#
# ********************************
# APD  starting:
# c:\python36\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# ...
#   lambda x: np.fabs(x - x.mean()).mean())
# c:\python36\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# WMT results:
# Train Accuracy: 65.20%
# Test Accuracy: 52.46%
# Return difference:  17.824626067862837
# Loop run-time:  2.0142979621887207
#
# ********************************
# WRK  starting:
# c:\python36\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# c:\python36\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
# c:\python36\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# WRK results:
# Train Accuracy: 69.44%
# Test Accuracy: 44.51%
# Return difference:  -12.176634980883222
# Loop run-time:  1.7662384510040283
#
# ********************************
# WU  starting:
# c:\python36\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# c:\python36\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
# c:\python36\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# WU results:
# Train Accuracy: 67.89%
# Test Accuracy: 54.10%
# Return difference:  11.200771157896835
# Loop run-time:  1.9183108806610107
#
# ********************************
# WY  starting:
# c:\python36\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# c:\python36\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
# c:\python36\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# WY results:
# Train Accuracy: 66.06%
# Test Accuracy: 51.64%
# Return difference:  0.5097639045444282
# Loop run-time:  2.215947389602661
#
# ********************************
# WYNN  starting:
# c:\python36\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# c:\python36\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
# c:\python36\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# WYNN results:
# Train Accuracy: 67.38%
# Test Accuracy: 47.95%
# Return difference:  62.00002489827026
# Loop run-time:  2.5049140453338623
#
# ********************************
# XEC  starting:
# c:\python36\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# c:\python36\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
# c:\python36\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# XEC results:
# Train Accuracy: 68.09%
# Test Accuracy: 46.72%
# Return difference:  -28.38829939515698
# Loop run-time:  1.8957879543304443
#
# ********************************
# XEL  starting:
# c:\python36\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# c:\python36\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
# c:\python36\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# XEL results:
# Train Accuracy: 66.33%
# Test Accuracy: 46.91%
# Return difference:  -34.49193923005605
# Loop run-time:  1.8279359340667725
#
# ********************************
# XLNX  starting:
# c:\python36\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# c:\python36\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
# c:\python36\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# XLNX results:
# Train Accuracy: 62.49%
# Test Accuracy: 53.28%
# Return difference:  9.741580091233999
# Loop run-time:  1.8374660015106201
#
# ********************************
# XOM  starting:
# c:\python36\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# c:\python36\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
# c:\python36\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# XOM results:
# Train Accuracy: 68.91%
# Test Accuracy: 51.23%
# Return difference:  -7.197481756602707
# Loop run-time:  1.7801918983459473
#
# ********************************
# XRAY  starting:
# c:\python36\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# c:\python36\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
# c:\python36\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# XRAY results:
# Train Accuracy: 68.60%
# Test Accuracy: 52.05%
# Return difference:  -36.65646652900867
# Loop run-time:  2.236438751220703
#
# ********************************
# XRX  starting:
# c:\python36\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# c:\python36\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
# c:\python36\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# XRX results:
# Train Accuracy: 65.85%
# Test Accuracy: 50.41%
# Return difference:  -37.74961658415627
# Loop run-time:  1.8853981494903564
#
# ********************************
# XYL  starting:
# c:\python36\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# c:\python36\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
# c:\python36\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# XYL results:
# Train Accuracy: 70.44%
# Test Accuracy: 49.59%
# Return difference:  0.06769487474198399
# Loop run-time:  1.9379432201385498
#
# ********************************
# YUM  starting:
# c:\python36\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# c:\python36\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
# c:\python36\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# YUM results:
# Train Accuracy: 63.30%
# Test Accuracy: 52.46%
# Return difference:  6.348010288563966
# Loop run-time:  1.8989057540893555
#
# ********************************
# ZBH  starting:
# c:\python36\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# c:\python36\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
# c:\python36\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# ZBH results:
# Train Accuracy: 66.73%
# Test Accuracy: 53.69%
# Return difference:  11.440096903014602
# Loop run-time:  1.9922044277191162
#
# ********************************
# ZION  starting:
# c:\python36\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# c:\python36\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
# c:\python36\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# ZION results:
# Train Accuracy: 65.75%
# Test Accuracy: 51.23%
# Return difference:  10.230476693803965
# Loop run-time:  2.1538963317871094
#
# ********************************
# ZTS  starting:
# c:\python36\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# c:\python36\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
# c:\python36\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# ZTS results:
# Train Accuracy: 67.58%
# Test Accuracy: 50.82%
# Return difference:  -4.3208849441733665
# Loop run-time:  1.8293962478637695
# Script run-time:  1010.3756847381592

# %%
# all-in-one KNN predictor on entirety of SP500

start = time.time()

accuracy_results = {}
returns = {}

for ticker in sp500:
    try:
        loop_start = time.time()
        #download current ticker data
        print(" ")
        print("********************************")
        print(ticker, " starting: ")
        Df = web.DataReader(ticker, 'iex', start="2014-01-01", end="2019-03-01")
        Df = Df.dropna()
        #print(Df.head())
        #Df.close.plot(figsize=(15,10))
        #plt.ylabel("AAPL Price")
        #plt.show()

        # create new "X" dataframe containing features
        Df['open-close'] = Df.open - Df.close
        Df['high-low'] = Df.high - Df.low
        #Df['change'] = Df['close'].pct_change().shift(-1) # recalculates change
        Df = ss.StockDataFrame.retype(Df) #coerces df into StockDataFrame
        Df['macd'] # calculate MACD indicator for the entire "btc" df and automatically appends to new column
        Df["rsi_6"]
        Df['volume_delta']
        Df['open_-1_r']
        Df['cr']
        Df['cr-ma1']
        Df['cr-ma2']
        Df['cr-ma3']
        Df["rsi_12"]
        Df["wr_10"]
        Df["cci"]
        Df['tr']
        Df['atr']
        Df['dma']
        Df['pdi']
        Df['mdi']
        Df['dx']
        Df['adx']
        Df['adxr']
        Df['trix']
        Df['trix_9_sma']
        Df['vr']
        Df = pd.DataFrame(Df)
        Df = Df.dropna()
        #X_temp = Df[['close','open-close','high-low']].iloc[2:,:]
        #X_temp = Df[['close','open-close','high-low', 'rs_6', 'rsi_6', 'macd', 'macds','macdh']].iloc[2:,:]
        X_temp = Df[['close','open-close','high-low', 'rs_6', 'rsi_6', 'macd', 'macds','macdh','close_26_ema','volume_delta','open_-1_r','middle','cr','cr-ma1','cr-ma2','cr-ma3','close_-1_s','close_-1_d','rs_6','rsi_6','rs_12','rsi_12','wr_10','middle_14_sma','cci','tr','atr','close_10_sma','close_50_sma','dma','high_delta','um','low_delta','dm','pdm','pdm_14_ema','pdm_14','atr_14','pdi_14','pdi','mdm','mdm_14_ema','mdm_14','mdi_14','mdi','dx_14','dx','dx_6_ema','adx','adx_6_ema','adxr','trix','trix_9_sma','vr']].iloc[2:,:]
        X_temp = X_temp.dropna()
                
        # create numpy array containing +1/-1 depending on yesterday's price change
        y = np.where(X_temp['close'].shift(-1) > X_temp['close'],1,-1)
        X = X_temp.drop(columns='close')
        
        # split data into training / test
        split_percentage = 0.8
        split = int(split_percentage*len(Df))
        #print("Split: ", split)
        # Train data set
        X_train = X[:split].values
        y_train = y[:split]
        # Test data set
        X_test = X[split:].values
        y_test = y[split:]
        #print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
        #print(y_test)

        # train
        sc = StandardScaler()
        X_train = sc.fit_transform(X_train)
        X_test = sc.transform(X_test)
        cls = KNeighborsClassifier().fit(X_train, y_train)

        # accuracies
        accuracy_train = accuracy_score(y_train, cls.predict(X_train))
        accuracy_test = accuracy_score(y_test, cls.predict(X_test))
        print(ticker, "results:")
        print('Train Accuracy:{: .2f}%'.format(accuracy_train*100))
        print('Test Accuracy:{: .2f}%'.format(accuracy_test*100))
        # append to accuracy_results dict
        accuracy_results[ticker] = (accuracy_train*100, accuracy_test*100)
        
        predicted_signal = cls.predict(X_test)
        return_ = np.log(X_temp[split:].close.shift(-1) / X_temp[split:].close)*100 #X_temp[split:] == X_test
        #return_ = (X_temp[split:].close.shift(-1) / X_temp[split:].close)*100 #X_temp[split:] == X_test
        strategy_return = return_ * predicted_signal
        #print("Return difference: ", strategy_return[split:].cumsum()[len(strategy_return)-2] - return_[split:].cumsum()[len(return_)-2])
        print("Return difference: ", strategy_return.cumsum()[len(strategy_return)-2] - return_.cumsum()[len(return_)-2])
        returns[ticker] = [accuracy_train*100, accuracy_test*100, return_.cumsum().iloc[-2], strategy_return.cumsum().iloc[-2]]
        
        loop_end = time.time()
        print("Loop run-time: ", (loop_end - loop_start))
        
        '''
        # calculate returns during testing only
        Df['Predicted_Signal'] = cls.predict(X)
        # Calculate log returns
        Df['Return'] = np.log(Df.close.shift(-1) / Df.close)*100
        Df['Strategy_Return'] = Df.Return * Df.Predicted_Signal
        print("Return difference: ", Df.Strategy_Return.iloc[split:].cumsum().iloc[-2]-Df.Return.iloc[split:].cumsum().iloc[-2])
        returns[ticker] = [Df.Return.iloc[split:].cumsum().iloc[-2], Df.Strategy_Return.iloc[split:].cumsum().iloc[-2]]
        '''
    except Exception as e: 
        print("ERROR: ", e)
        print(ticker, "FAILED!!!")
        accuracy_results[ticker] = (0,0)
        returns[ticker] = [0,0,0,0]
        loop_end = time.time()
        print("Loop run-time: ", (loop_end - loop_start))
        
end = time.time()
print("Script run-time: ", (end - start))
        
df_returns = pd.DataFrame.from_dict(returns, columns=['Train Accuracy','Test Accuracy','Hold Return', 'Strategy Return'], orient='index')
df_returns.to_csv("stockstats_testing_returns.csv")

winsound.Beep(1000,1000)
# Out:
#
# ********************************
# A  starting:
# c:\python36\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# c:\python36\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
# c:\python36\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# A results:
# Train Accuracy: 68.06%
# Test Accuracy: 49.59%
# Return difference:  -47.45202660116658
# Loop run-time:  2.5998854637145996
#
# ********************************
# AAL  starting:
# c:\python36\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# c:\python36\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
# c:\python36\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# AAL results:
# Train Accuracy: 70.51%
# Test Accuracy: 55.74%
# Return difference:  89.6665968924946
# Loop run-time:  1.7259953022003174
#
# ********************************
# AAP  starting:
# c:\python36\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# c:\python36\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
# c:\python36\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# AAP results:
# Train Accuracy: 69.90%
# Test Accuracy: 47.54%
# Return difference:  -45.2583273870971
# Loop run-time:  1.482870101928711
#
# ********************************
# AAPL  starting:
# c:\python36\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# c:\python36\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
# c:\python36\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# AAPL results:
# Train Accuracy: 70.10%
# Test Accuracy: 47.13%
# Return difference:  -20.87978367217076
# Loop run-time:  1.9165513515472412
#
# ********************************
# ABBV  starting:
# c:\python36\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# c:\python36\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
# c:\python36\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# ABBV results:
# Train Accuracy: 70.51%
# Test Accuracy: 47.95%
# Return difference:  14.2035152674434
# Loop run-time:  2.3558804988861084
#
# ********************************
# ABC  starting:
# c:\python36\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# c:\python36\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
# c:\python36\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# ABC results:
# Train Accuracy: 70.41%
# Test Accuracy: 53.69%
# Return difference:  38.38657047542375
# Loop run-time:  2.0881855487823486
#
# ********************************
# ABMD  starting:
# c:\python36\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# c:\python36\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
# c:\python36\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# ABMD results:
# Train Accuracy: 70.10%
# Test Accuracy: 48.77%
# Return difference:  3.0591460401477626
# Loop run-time:  1.686828851699829
#
# ********************************
# ABT  starting:
# c:\python36\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# c:\python36\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
# c:\python36\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# ABT results:
# Train Accuracy: 70.10%
# Test Accuracy: 58.85%
# Return difference:  21.84680517504888
# Loop run-time:  1.969658374786377
#
# ********************************
# ACN  starting:
# c:\python36\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# c:\python36\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
# c:\python36\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# ACN results:
# Train Accuracy: 69.39%
# Test Accuracy: 54.10%
# Return difference:  6.95986918322822
# Loop run-time:  2.4957025051116943
#
# ********************************
# ADBE  starting:
# c:\python36\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# c:\python36\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
# c:\python36\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# ADBE results:
# Train Accuracy: 67.76%
# Test Accuracy: 54.92%
# Return difference:  31.110798874820198
# Loop run-time:  1.7742877006530762
#
# ********************************
# ADI  starting:
# c:\python36\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# c:\python36\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
# c:\python36\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# ADI results:
# Train Accuracy: 71.12%
# Test Accuracy: 56.15%
# Return difference:  21.960294721405475
# Loop run-time:  2.0756607055664062
#
# ********************************
# ADM  starting:
# c:\python36\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# c:\python36\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
# c:\python36\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# ADM results:
# Train Accuracy: 69.90%
# Test Accuracy: 48.36%
# Return difference:  -15.376523388032346
# Loop run-time:  1.8001320362091064
#
# ********************************
# ADP  starting:
# c:\python36\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# c:\python36\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
# c:\python36\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# ADP results:
# Train Accuracy: 69.08%
# Test Accuracy: 46.72%
# Return difference:  -42.08382716405586
# Loop run-time:  2.455524206161499
#
# ********************************
# ADS  starting:
# c:\python36\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# c:\python36\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
# c:\python36\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# ADS results:
# Train Accuracy: 71.63%
# Test Accuracy: 48.77%
# Return difference:  38.26164466572449
# Loop run-time:  2.1833555698394775
#
# ********************************
# ADSK  starting:
# c:\python36\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# c:\python36\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
# c:\python36\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# ADSK results:
# Train Accuracy: 70.41%
# Test Accuracy: 52.05%
# Return difference:  10.978027437185752
# Loop run-time:  1.307379961013794
#
# ********************************
# AEE  starting:
# c:\python36\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# c:\python36\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
# c:\python36\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# AEE results:
# Train Accuracy: 67.76%
# Test Accuracy: 47.54%
# Return difference:  -50.351762665067824
# Loop run-time:  1.930771827697754
#
# ********************************
# AEP  starting:
# c:\python36\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# c:\python36\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
# c:\python36\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# AEP results:
# Train Accuracy: 70.51%
# Test Accuracy: 50.21%
# Return difference:  -24.807106775436626
# Loop run-time:  2.023380756378174
#
# ********************************
# AES  starting:
# c:\python36\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# c:\python36\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
# c:\python36\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# AES results:
# Train Accuracy: 68.47%
# Test Accuracy: 46.72%
# Return difference:  -66.43556088932583
# Loop run-time:  1.9061319828033447
#
# ********************************
# AFL  starting:
# c:\python36\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# c:\python36\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
# c:\python36\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# AFL results:
# Train Accuracy: 69.80%
# Test Accuracy: 48.77%
# Return difference:  -10.488950431673961
# Loop run-time:  1.9875717163085938
#
# ********************************
# AGN  starting:
# c:\python36\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# c:\python36\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
# c:\python36\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# AGN results:
# Train Accuracy: 67.04%
# Test Accuracy: 50.41%
# Return difference:  -1.6509769844710291
# Loop run-time:  2.135200023651123
#
# ********************************
# AIG  starting:
# c:\python36\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# c:\python36\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
# c:\python36\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# AIG results:
# Train Accuracy: 70.82%
# Test Accuracy: 51.64%
# Return difference:  15.41319708252388
# Loop run-time:  1.8439629077911377
#
# ********************************
# AIV  starting:
# c:\python36\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# c:\python36\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
# c:\python36\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# AIV results:
# Train Accuracy: 66.22%
# Test Accuracy: 51.23%
# Return difference:  -4.201131766759797
# Loop run-time:  1.5613114833831787
#
# ********************************
# AIZ  starting:
# c:\python36\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# c:\python36\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
# c:\python36\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# AIZ results:
# Train Accuracy: 69.90%
# Test Accuracy: 47.95%
# Return difference:  -35.75150402173223
# Loop run-time:  1.720649003982544
#
# ********************************
# AJG  starting:
# c:\python36\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# c:\python36\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
# c:\python36\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# AJG results:
# Train Accuracy: 71.43%
# Test Accuracy: 53.69%
# Return difference:  2.960005159713022
# Loop run-time:  1.4000792503356934
#
# ********************************
# AKAM  starting:
# c:\python36\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# c:\python36\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
# c:\python36\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# AKAM results:
# Train Accuracy: 69.80%
# Test Accuracy: 47.95%
# Return difference:  -22.73061594596151
# Loop run-time:  1.962684154510498
#
# ********************************
# ALB  starting:
# c:\python36\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# c:\python36\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
# c:\python36\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# ALB results:
# Train Accuracy: 69.90%
# Test Accuracy: 52.46%
# Return difference:  13.836633312789019
# Loop run-time:  1.5667212009429932
#
# ********************************
# ALGN  starting:
# c:\python36\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# c:\python36\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
# c:\python36\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# ALGN results:
# Train Accuracy: 69.69%
# Test Accuracy: 51.44%
# Return difference:  -21.01708114471724
# Loop run-time:  1.849402904510498
#
# ********************************
# ALK  starting:
# c:\python36\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# c:\python36\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
# c:\python36\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# ALK results:
# Train Accuracy: 65.82%
# Test Accuracy: 49.18%
# Return difference:  -2.6972956367509386
# Loop run-time:  1.9982891082763672
#
# ********************************
# ALL  starting:
# c:\python36\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# c:\python36\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
# c:\python36\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# ALL results:
# Train Accuracy: 71.43%
# Test Accuracy: 47.13%
# Return difference:  -23.771092196978607
# Loop run-time:  1.9764840602874756
#
# ********************************
# ALLE  starting:
# c:\python36\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# c:\python36\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
# c:\python36\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# ALLE results:
# Train Accuracy: 68.57%
# Test Accuracy: 49.18%
# Return difference:  -24.543408508716315
# Loop run-time:  1.8161754608154297
#
# ********************************
# ALXN  starting:
# c:\python36\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# c:\python36\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
# c:\python36\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# ALXN results:
# Train Accuracy: 69.08%
# Test Accuracy: 52.46%
# Return difference:  31.366826114641533
# Loop run-time:  1.9553310871124268
#
# ********************************
# AMAT  starting:
# c:\python36\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# c:\python36\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
# c:\python36\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# AMAT results:
# Train Accuracy: 69.39%
# Test Accuracy: 52.05%
# Return difference:  74.96097648171558
# Loop run-time:  1.593630075454712
#
# ********************************
# AMD  starting:
# c:\python36\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# c:\python36\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
# c:\python36\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# AMD results:
# Train Accuracy: 69.29%
# Test Accuracy: 54.10%
# Return difference:  -101.22098180491486
# Loop run-time:  1.3137803077697754
#
# ********************************
# AME  starting:
# c:\python36\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# c:\python36\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
# c:\python36\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# AME results:
# Train Accuracy: 70.20%
# Test Accuracy: 48.77%
# Return difference:  -2.4778309931393703
# Loop run-time:  1.363133192062378
#
# ********************************
# AMG  starting:
# c:\python36\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# c:\python36\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
# c:\python36\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# AMG results:
# Train Accuracy: 69.69%
# Test Accuracy: 45.49%
# Return difference:  25.642577978926955
# Loop run-time:  1.7189760208129883
#
# ********************************
# AMGN  starting:
# c:\python36\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# c:\python36\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
# c:\python36\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# AMGN results:
# Train Accuracy: 68.78%
# Test Accuracy: 47.95%
# Return difference:  -2.4956840687175488
# Loop run-time:  1.9655847549438477
#
# ********************************
# AMP  starting:
# c:\python36\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# c:\python36\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
# c:\python36\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# AMP results:
# Train Accuracy: 70.31%
# Test Accuracy: 53.69%
# Return difference:  59.89797895630197
# Loop run-time:  1.8477895259857178
#
# ********************************
# AMT  starting:
# c:\python36\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# c:\python36\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
# c:\python36\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# AMT results:
# Train Accuracy: 69.08%
# Test Accuracy: 50.82%
# Return difference:  7.498397550783675
# Loop run-time:  1.9827964305877686
#
# ********************************
# AMZN  starting:
# c:\python36\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# c:\python36\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
# c:\python36\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# AMZN results:
# Train Accuracy: 68.98%
# Test Accuracy: 54.92%
# Return difference:  14.017487104593307
# Loop run-time:  2.3808653354644775
#
# ********************************
# ANET  starting:
# c:\python36\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# c:\python36\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
# c:\python36\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# ANET results:
# Train Accuracy: 68.36%
# Test Accuracy: 54.04%
# Return difference:  38.356775707749534
# Loop run-time:  1.7998042106628418
#
# ********************************
# ANSS  starting:
# c:\python36\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# c:\python36\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
# c:\python36\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# ANSS results:
# Train Accuracy: 71.22%
# Test Accuracy: 53.28%
# Return difference:  0.1710960098686467
# Loop run-time:  1.9603240489959717
#
# ********************************
# ANTM  starting:
# c:\python36\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# c:\python36\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
# c:\python36\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# ANTM results:
# Train Accuracy: 70.61%
# Test Accuracy: 44.67%
# Return difference:  -68.57370143161837
# Loop run-time:  1.857550859451294
#
# ********************************
# AON  starting:
# c:\python36\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# c:\python36\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
# c:\python36\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# AON results:
# Train Accuracy: 67.24%
# Test Accuracy: 52.87%
# Return difference:  -21.524941758575235
# Loop run-time:  1.784731149673462
#
# ********************************
# AOS  starting:
# c:\python36\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# c:\python36\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
# c:\python36\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# AOS results:
# Train Accuracy: 69.80%
# Test Accuracy: 47.95%
# Return difference:  19.056793587338362
# Loop run-time:  1.5392966270446777
#
# ********************************
# APA  starting:
# c:\python36\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# c:\python36\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
# c:\python36\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# APA results:
# Train Accuracy: 68.78%
# Test Accuracy: 48.56%
# Return difference:  2.9577713944841904
# Loop run-time:  2.1703402996063232
#
# ********************************
# APC  starting:
# c:\python36\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# c:\python36\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
# c:\python36\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# APC results:
# Train Accuracy: 69.90%
# Test Accuracy: 48.97%
# Return difference:  -4.013741072171204
# Loop run-time:  1.505659580230713
#
# ********************************
# APD  starting:
# c:\python36\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# ...
#   lambda x: np.fabs(x - x.mean()).mean())
# c:\python36\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# WMT results:
# Train Accuracy: 66.73%
# Test Accuracy: 51.64%
# Return difference:  4.2770017349706375
# Loop run-time:  1.3854100704193115
#
# ********************************
# WRK  starting:
# c:\python36\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# c:\python36\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
# c:\python36\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# WRK results:
# Train Accuracy: 70.12%
# Test Accuracy: 48.35%
# Return difference:  62.68931923697184
# Loop run-time:  1.6193721294403076
#
# ********************************
# WU  starting:
# c:\python36\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# c:\python36\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
# c:\python36\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# WU results:
# Train Accuracy: 64.18%
# Test Accuracy: 49.18%
# Return difference:  -8.077449034663662
# Loop run-time:  2.1509416103363037
#
# ********************************
# WY  starting:
# c:\python36\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# c:\python36\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
# c:\python36\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# WY results:
# Train Accuracy: 70.00%
# Test Accuracy: 52.05%
# Return difference:  29.917544884437024
# Loop run-time:  2.0485618114471436
#
# ********************************
# WYNN  starting:
# c:\python36\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# c:\python36\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
# c:\python36\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# WYNN results:
# Train Accuracy: 70.61%
# Test Accuracy: 45.08%
# Return difference:  2.711436546639284
# Loop run-time:  2.0425684452056885
#
# ********************************
# XEC  starting:
# c:\python36\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# c:\python36\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
# c:\python36\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# XEC results:
# Train Accuracy: 67.96%
# Test Accuracy: 51.23%
# Return difference:  29.859831083661273
# Loop run-time:  2.0884957313537598
#
# ********************************
# XEL  starting:
# c:\python36\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# c:\python36\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
# c:\python36\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# XEL results:
# Train Accuracy: 69.29%
# Test Accuracy: 52.26%
# Return difference:  -9.355951107080372
# Loop run-time:  1.888880968093872
#
# ********************************
# XLNX  starting:
# c:\python36\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# c:\python36\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
# c:\python36\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# XLNX results:
# Train Accuracy: 67.45%
# Test Accuracy: 51.64%
# Return difference:  -3.8714183735618235
# Loop run-time:  2.1016359329223633
#
# ********************************
# XOM  starting:
# c:\python36\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# c:\python36\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
# c:\python36\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# XOM results:
# Train Accuracy: 68.67%
# Test Accuracy: 53.28%
# Return difference:  -4.570957148692511
# Loop run-time:  1.4359991550445557
#
# ********************************
# XRAY  starting:
# c:\python36\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# c:\python36\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
# c:\python36\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# XRAY results:
# Train Accuracy: 68.67%
# Test Accuracy: 51.23%
# Return difference:  53.08324286617362
# Loop run-time:  1.7899479866027832
#
# ********************************
# XRX  starting:
# c:\python36\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# c:\python36\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
# c:\python36\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# XRX results:
# Train Accuracy: 70.51%
# Test Accuracy: 48.36%
# Return difference:  -38.466351040647865
# Loop run-time:  1.6104199886322021
#
# ********************************
# XYL  starting:
# c:\python36\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# c:\python36\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
# c:\python36\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# XYL results:
# Train Accuracy: 70.82%
# Test Accuracy: 52.05%
# Return difference:  14.066460900912544
# Loop run-time:  1.4504938125610352
#
# ********************************
# YUM  starting:
# c:\python36\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# c:\python36\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
# c:\python36\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# YUM results:
# Train Accuracy: 66.73%
# Test Accuracy: 52.05%
# Return difference:  19.232063158583692
# Loop run-time:  1.8521361351013184
#
# ********************************
# ZBH  starting:
# c:\python36\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# c:\python36\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
# c:\python36\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# ZBH results:
# Train Accuracy: 68.78%
# Test Accuracy: 52.87%
# Return difference:  -2.539290416469326
# Loop run-time:  1.4365665912628174
#
# ********************************
# ZION  starting:
# c:\python36\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# c:\python36\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
# c:\python36\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# ZION results:
# Train Accuracy: 70.31%
# Test Accuracy: 51.64%
# Return difference:  -3.99749019323003
# Loop run-time:  1.916639804840088
#
# ********************************
# ZTS  starting:
# c:\python36\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# c:\python36\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
# c:\python36\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# ZTS results:
# Train Accuracy: 72.65%
# Test Accuracy: 49.59%
# Return difference:  -5.8020338732944685
# Loop run-time:  2.018569231033325
# Script run-time:  957.5117914676666

# %%
#Df = pdr.get_data_fred('SPY', start="2012-01-01", end="2017-10-01")
Df = web.DataReader('AAPL', 'iex', start="2014-01-01", end="2019-03-01")
Df = Df.dropna()
#print(Df.head())
Df.close.plot(figsize=(15,10))
plt.ylabel("AAPL Price")
plt.show()
print(type(Df))

# %%
y = np.where(Df['close'].shift(-1) > Df['close'],1,-1)
print(y)
print(type(y))

# %%
Df['open-close'] = Df.open - Df.close
Df['high-low'] = Df.high - Df.low
 
X = Df[['open-close','high-low']]

# %%
split_percentage = 0.8
split = int(split_percentage*len(Df))
 
# Train data set
X_train = X[:split]
y_train = y[:split]
 
# Test data set
X_test = X[split:]
y_test = y[split:]

# %%
cls = SVC().fit(X_train, y_train)
# Out:
# C:\Python35\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)

# %%
accuracy_train = accuracy_score(y_train, cls.predict(X_train))
accuracy_test = accuracy_score(y_test, cls.predict(X_test))

print('\nTrain Accuracy:{: .2f}%'.format(accuracy_train*100))
print('Test Accuracy:{: .2f}%'.format(accuracy_test*100))
# Out:
# Train Accuracy: 54.26%
# Test Accuracy: 48.00%

# %%
Df['Predicted_Signal'] = cls.predict(X)
 
# Calculate log returns
Df['Return'] = np.log(Df.close.shift(-1) / Df.close)*100
Df['Strategy_Return'] = Df.Return * Df.Predicted_Signal
Df.Strategy_Return.iloc[split:].cumsum().plot(figsize=(10,5))
plt.ylabel("Strategy Returns (%)")
plt.show()

# %%
Df['Predicted_Signal'] = cls.predict(X)
 
# Calculate log returns
Df['Return'] = np.log(Df.close.shift(-1) / Df.close)*100
Df['Strategy_Return'] = Df.Return * Df.Predicted_Signal

print(Df.Strategy_Return.iloc[split:].cumsum().iloc[-2])
print(Df.Return.iloc[split:].cumsum().iloc[-2])
# Out:
# 29.297527891147606
# 16.26381195218327

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-e3d77f7035e5> in <module>
#       1 # all-in-one SVC predictor on entirety of SP500
#       2
# ----> 3 start = time.time()
#       4
#       5 accuracy_results = {}
#
# NameError: name 'time' is not defined

# %%
# Out:
#
# ********************************
# A  starting:
# C:\Python35\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Python35\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
#  A  results:
# Train Accuracy: 68.81%
# Test Accuracy: 49.59%
# Return difference:  -47.45202660116658
#
# ********************************
# AAL  starting:
# C:\Python35\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Python35\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
#  AAL  results:
# Train Accuracy: 70.64%
# Test Accuracy: 55.33%
# Return difference:  83.93164360340637
#
# ********************************
# AAP  starting:
# C:\Python35\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Python35\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
#  AAP  results:
# Train Accuracy: 69.93%
# Test Accuracy: 47.54%
# Return difference:  -45.825330807211174
#
# ********************************
# AAPL  starting:
# C:\Python35\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Python35\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
#  AAPL  results:
# Train Accuracy: 70.03%
# Test Accuracy: 47.13%
# Return difference:  -20.87978367217076
#
# ********************************
# ABBV  starting:
# C:\Python35\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Python35\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
#  ABBV  results:
# Train Accuracy: 70.41%
# Test Accuracy: 47.95%
# Return difference:  14.2035152674434
#
# ********************************
# ABC  starting:
# C:\Python35\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Python35\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
#  ABC  results:
# Train Accuracy: 70.34%
# Test Accuracy: 53.69%
# Return difference:  38.38657047542375
#
# ********************************
# ABMD  starting:
# C:\Python35\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Python35\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
#  ABMD  results:
# Train Accuracy: 70.03%
# Test Accuracy: 48.77%
# Return difference:  3.0591460401477626
#
# ********************************
# ABT  starting:
# C:\Python35\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Python35\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
#  ABT  results:
# Train Accuracy: 69.93%
# Test Accuracy: 58.20%
# Return difference:  13.262165959554828
#
# ********************************
# ACN  starting:
# C:\Python35\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Python35\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
#  ACN  results:
# Train Accuracy: 69.72%
# Test Accuracy: 54.51%
# Return difference:  10.438437620956991
#
# ********************************
# ADBE  starting:
# C:\Python35\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Python35\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
#  ADBE  results:
# Train Accuracy: 67.38%
# Test Accuracy: 55.33%
# Return difference:  33.08883697631067
#
# ********************************
# ADI  starting:
# C:\Python35\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Python35\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
#  ADI  results:
# Train Accuracy: 71.15%
# Test Accuracy: 56.15%
# Return difference:  21.960294721405475
#
# ********************************
# ADM  starting:
# C:\Python35\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Python35\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
#  ADM  results:
# Train Accuracy: 70.23%
# Test Accuracy: 50.41%
# Return difference:  7.044767464919425
#
# ********************************
# ADP  starting:
# C:\Python35\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Python35\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
#  ADP  results:
# Train Accuracy: 69.11%
# Test Accuracy: 46.72%
# Return difference:  -42.08382716405586
#
# ********************************
# ADS  starting:
# C:\Python35\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Python35\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
#  ADS  results:
# Train Accuracy: 71.87%
# Test Accuracy: 48.36%
# Return difference:  35.99966657297146
#
# ********************************
# ADSK  starting:
# C:\Python35\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Python35\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
#  ADSK  results:
# Train Accuracy: 70.54%
# Test Accuracy: 52.05%
# Return difference:  14.596741949237874
#
# ********************************
# AEE  starting:
# C:\Python35\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Python35\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
#  AEE  results:
# Train Accuracy: 67.89%
# Test Accuracy: 47.54%
# Return difference:  -50.351762665067824
#
# ********************************
# AEP  starting:
# C:\Python35\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Python35\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
#  AEP  results:
# Train Accuracy: 72.38%
# Test Accuracy: 48.36%
# Return difference:  -37.60645374217259
#
# ********************************
# AES  starting:
# C:\Python35\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Python35\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
#  AES  results:
# Train Accuracy: 68.81%
# Test Accuracy: 45.90%
# Return difference:  -90.01548014168714
#
# ********************************
# AFL  starting:
# C:\Python35\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Python35\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
#  AFL  results:
# Train Accuracy: 70.00%
# Test Accuracy: 49.18%
# Return difference:  -3.6242235611011457
#
# ********************************
# AGN  starting:
# C:\Python35\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Python35\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
#  AGN  results:
# Train Accuracy: 66.77%
# Test Accuracy: 50.82%
# Return difference:  0.10721353396352384
#
# ********************************
# AIG  starting:
# C:\Python35\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Python35\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
#  AIG  results:
# Train Accuracy: 70.92%
# Test Accuracy: 51.64%
# Return difference:  17.154078234583302
#
# ********************************
# AIV  starting:
# C:\Python35\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Python35\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
#  AIV  results:
# Train Accuracy: 66.77%
# Test Accuracy: 51.23%
# Return difference:  -1.1276407974161522
#
# ********************************
# AIZ  starting:
# C:\Python35\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Python35\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
#  AIZ  results:
# Train Accuracy: 69.90%
# Test Accuracy: 47.95%
# Return difference:  -35.75150402173223
#
# ********************************
# AJG  starting:
# C:\Python35\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Python35\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
#  AJG  results:
# Train Accuracy: 71.25%
# Test Accuracy: 53.69%
# Return difference:  2.960005159713022
#
# ********************************
# AKAM  starting:
# C:\Python35\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Python35\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
#  AKAM  results:
# Train Accuracy: 69.52%
# Test Accuracy: 47.95%
# Return difference:  -22.73061594596151
#
# ********************************
# ALB  starting:
# C:\Python35\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Python35\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
#  ALB  results:
# Train Accuracy: 70.03%
# Test Accuracy: 52.46%
# Return difference:  13.836633312789019
#
# ********************************
# ALGN  starting:
# C:\Python35\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Python35\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
#  ALGN  results:
# Train Accuracy: 69.52%
# Test Accuracy: 50.00%
# Return difference:  -35.919239568194754
#
# ********************************
# ALK  starting:
# C:\Python35\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Python35\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
#  ALK  results:
# Train Accuracy: 65.85%
# Test Accuracy: 49.18%
# Return difference:  -2.6972956367509386
#
# ********************************
# ALL  starting:
# C:\Python35\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Python35\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
#  ALL  results:
# Train Accuracy: 71.53%
# Test Accuracy: 46.72%
# Return difference:  -24.84794641806448
#
# ********************************
# ALLE  starting:
# C:\Python35\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Python35\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
#  ALLE  results:
# Train Accuracy: 68.78%
# Test Accuracy: 48.77%
# Return difference:  -25.76158480849298
#
# ********************************
# ALXN  starting:
# C:\Python35\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Python35\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
#  ALXN  results:
# Train Accuracy: 69.01%
# Test Accuracy: 52.87%
# Return difference:  33.494505755652675
#
# ********************************
# AMAT  starting:
# C:\Python35\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Python35\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
#  AMAT  results:
# Train Accuracy: 69.18%
# Test Accuracy: 52.05%
# Return difference:  74.96097648171558
#
# ********************************
# AMD  starting:
# C:\Python35\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Python35\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
#  AMD  results:
# Train Accuracy: 69.22%
# Test Accuracy: 53.69%
# Return difference:  -107.41902460826802
#
# ********************************
# AME  starting:
# C:\Python35\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Python35\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
#  AME  results:
# Train Accuracy: 69.93%
# Test Accuracy: 48.77%
# Return difference:  -2.4778309931393703
#
# ********************************
# AMG  starting:
# C:\Python35\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Python35\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
#  AMG  results:
# Train Accuracy: 69.32%
# Test Accuracy: 45.49%
# Return difference:  25.642577978926955
#
# ********************************
# AMGN  starting:
# C:\Python35\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Python35\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
#  AMGN  results:
# Train Accuracy: 68.81%
# Test Accuracy: 47.95%
# Return difference:  -2.4956840687175488
#
# ********************************
# AMP  starting:
# C:\Python35\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Python35\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
#  AMP  results:
# Train Accuracy: 70.34%
# Test Accuracy: 53.69%
# Return difference:  59.89797895630197
#
# ********************************
# AMT  starting:
# C:\Python35\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Python35\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
#  AMT  results:
# Train Accuracy: 69.22%
# Test Accuracy: 50.41%
# Return difference:  6.950431519624235
#
# ********************************
# AMZN  starting:
# C:\Python35\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Python35\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
#  AMZN  results:
# Train Accuracy: 69.11%
# Test Accuracy: 54.92%
# Return difference:  14.017487104593307
#
# ********************************
# ANET  starting:
# C:\Python35\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Python35\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
#  ANET  results:
# Train Accuracy: 68.36%
# Test Accuracy: 54.04%
# Return difference:  38.356775707749534
#
# ********************************
# ANSS  starting:
# C:\Python35\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Python35\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
#  ANSS  results:
# Train Accuracy: 71.15%
# Test Accuracy: 53.28%
# Return difference:  0.1710960098686467
#
# ********************************
# ANTM  starting:
# C:\Python35\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Python35\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
#  ANTM  results:
# Train Accuracy: 71.33%
# Test Accuracy: 44.26%
# Return difference:  -69.10621525708402
#
# ********************************
# AON  starting:
# C:\Python35\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Python35\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
#  AON  results:
# Train Accuracy: 67.28%
# Test Accuracy: 52.87%
# Return difference:  -21.524941758575235
#
# ********************************
# AOS  starting:
# C:\Python35\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Python35\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
#  AOS  results:
# Train Accuracy: 69.93%
# Test Accuracy: 47.95%
# Return difference:  19.056793587338362
#
# ********************************
# APA  starting:
# C:\Python35\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Python35\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
#  APA  results:
# Train Accuracy: 68.67%
# Test Accuracy: 48.56%
# Return difference:  2.9577713944841904
#
# ********************************
# APC  starting:
# C:\Python35\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Python35\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
#  APC  results:
# Train Accuracy: 70.44%
# Test Accuracy: 47.54%
# Return difference:  19.916421004163606
#
# ********************************
# APD  starting:
# C:\Python35\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Python35\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
#  APD  results:
# Train Accuracy: 67.99%
# Test Accuracy: 53.69%
# Return difference:  9.625795607456599
#
# ********************************
# APH  starting:
# C:\Python35\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Python35\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
#  APH  results:
# Train Accuracy: 70.34%
# Test Accuracy: 54.92%
# Return difference:  15.226920198168703
#
# ********************************
# APTV  starting:
# C:\Python35\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Python35\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
#  APTV  results:
# Train Accuracy: 65.00%
# Test Accuracy: 46.55%
# Return difference:  -21.458946472584987
#
# ********************************
# ARE  starting:
# C:\Python35\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Python35\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
#  ARE  results:
# Train Accuracy: 69.22%
# Test Accuracy: 56.97%
# Return difference:  11.601770055939276
#
# ********************************
# ARNC  starting:
# C:\Python35\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Python35\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
#  ARNC  results:
# Train Accuracy: 70.44%
# Test Accuracy: 51.23%
# Return difference:  15.535158111017742
#
# ********************************
# ATO  starting:
# C:\Python35\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Python35\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
#  ATO  results:
# Train Accuracy: 70.82%
# Test Accuracy: 51.23%
# Return difference:  -9.240249721659579
#
# ********************************
# ATVI  starting:
# C:\Python35\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Python35\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
#  ATVI  results:
# Train Accuracy: 69.62%
# Test Accuracy: 53.28%
# Return difference:  73.24079924878204
#
# ********************************
# AVB  starting:
# C:\Python35\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Python35\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
#  AVB  results:
# Train Accuracy: 71.12%
# Test Accuracy: 55.74%
# Return difference:  -5.652975653481558
#
# ********************************
# AVGO  starting:
# C:\Python35\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Python35\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
#  AVGO  results:
# Train Accuracy: 71.15%
# Test Accuracy: 50.00%
# Return difference:  -22.783420686417244
#
# ********************************
# AVY  starting:
# C:\Python35\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Python35\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
#  AVY  results:
# Train Accuracy: 69.01%
# Test Accuracy: 52.87%
# Return difference:  2.6844192998429675
#
# ********************************
# AWK  starting:
# C:\Python35\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Python35\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
#  AWK  results:
# Train Accuracy: 67.96%
# Test Accuracy: 55.33%
# Return difference:  -6.829119126375097
#
# ********************************
# AXP  starting:
# C:\Python35\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Python35\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
#  AXP  results:
# Train Accuracy: 69.62%
# Test Accuracy: 50.00%
# ...
#   lambda x: np.fabs(x - x.mean()).mean())
#  WHR  results:
# Train Accuracy: 69.42%
# Test Accuracy: 50.00%
# Return difference:  3.126855491242897
#
# ********************************
# WLTW  starting:
# C:\Python35\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Python35\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
#  WLTW  results:
# Train Accuracy: 69.54%
# Test Accuracy: 53.55%
# Return difference:  3.289673100782304
#
# ********************************
# WM  starting:
# C:\Python35\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Python35\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
#  WM  results:
# Train Accuracy: 69.83%
# Test Accuracy: 50.41%
# Return difference:  -14.409505126571272
#
# ********************************
# WMB  starting:
# C:\Python35\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Python35\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
#  WMB  results:
# Train Accuracy: 71.05%
# Test Accuracy: 45.90%
# Return difference:  -53.14051144810823
#
# ********************************
# WMT  starting:
# C:\Python35\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Python35\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
#  WMT  results:
# Train Accuracy: 66.53%
# Test Accuracy: 50.00%
# Return difference:  -2.9593683673688815
#
# ********************************
# WRK  starting:
# C:\Python35\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Python35\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
#  WRK  results:
# Train Accuracy: 70.12%
# Test Accuracy: 48.35%
# Return difference:  62.68931923697184
#
# ********************************
# WU  starting:
# C:\Python35\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Python35\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
#  WU  results:
# Train Accuracy: 64.22%
# Test Accuracy: 49.18%
# Return difference:  -8.077449034663662
#
# ********************************
# WY  starting:
# C:\Python35\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Python35\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
#  WY  results:
# Train Accuracy: 70.13%
# Test Accuracy: 52.05%
# Return difference:  29.917544884437024
#
# ********************************
# WYNN  starting:
# C:\Python35\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Python35\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
#  WYNN  results:
# Train Accuracy: 70.54%
# Test Accuracy: 45.08%
# Return difference:  2.711436546639284
#
# ********************************
# XEC  starting:
# C:\Python35\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Python35\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
#  XEC  results:
# Train Accuracy: 67.89%
# Test Accuracy: 51.23%
# Return difference:  29.859831083661273
#
# ********************************
# XEL  starting:
# C:\Python35\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Python35\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
#  XEL  results:
# Train Accuracy: 68.98%
# Test Accuracy: 52.67%
# Return difference:  -11.067932080379496
#
# ********************************
# XLNX  starting:
# C:\Python35\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Python35\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
#  XLNX  results:
# Train Accuracy: 67.69%
# Test Accuracy: 52.05%
# Return difference:  -3.3469566274828964
#
# ********************************
# XOM  starting:
# C:\Python35\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Python35\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
#  XOM  results:
# Train Accuracy: 68.30%
# Test Accuracy: 53.28%
# Return difference:  -5.937146308727611
#
# ********************************
# XRAY  starting:
# C:\Python35\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Python35\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
#  XRAY  results:
# Train Accuracy: 68.60%
# Test Accuracy: 52.05%
# Return difference:  62.821986211622416
#
# ********************************
# XRX  starting:
# C:\Python35\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Python35\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
#  XRX  results:
# Train Accuracy: 69.83%
# Test Accuracy: 53.28%
# Return difference:  -23.393094470784366
#
# ********************************
# XYL  starting:
# C:\Python35\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Python35\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
#  XYL  results:
# Train Accuracy: 70.74%
# Test Accuracy: 52.05%
# Return difference:  14.066460900912544
#
# ********************************
# YUM  starting:
# C:\Python35\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Python35\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
#  YUM  results:
# Train Accuracy: 66.56%
# Test Accuracy: 52.05%
# Return difference:  19.232063158583692
#
# ********************************
# ZBH  starting:
# C:\Python35\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Python35\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
#  ZBH  results:
# Train Accuracy: 68.98%
# Test Accuracy: 53.28%
# Return difference:  -2.215226312403578
#
# ********************************
# ZION  starting:
# C:\Python35\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Python35\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
#  ZION  results:
# Train Accuracy: 70.34%
# Test Accuracy: 51.64%
# Return difference:  -3.99749019323003
#
# ********************************
# ZTS  starting:
# C:\Python35\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Python35\lib\site-packages\stockstats.py:387: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   lambda x: np.fabs(x - x.mean()).mean())
#  ZTS  results:
# Train Accuracy: 72.68%
# Test Accuracy: 49.59%
# Return difference:  -5.8020338732944685

# %%
cls = KNeighborsClassifier().fit(X_train, y_train)
cls = SVC().fit(X_train, y_train)

# %%
df_returns = pd.DataFrame.from_dict(returns, columns=['Hold Return', 'Strategy Return'], orient='index')
df_returns.to_csv("simple_testing_returns.csv")

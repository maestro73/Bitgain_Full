# %%
from pandas_datareader import data
import matplotlib.pyplot as plt
import pandas as pd
import pickle

# %%
tickers = ['AAPL', 'MSFT', 'GOOG']

# We would like all available data from 01/01/2000 until 12/31/2016.
start_date = '2015-01-01'
end_date = '2017-01-01'

# User pandas_reader.data.DataReader to load the desired data. As simple as that.
panel_data = data.DataReader(tickers, 'iex', start_date, end_date)

# %%
panel_data
# Out:
# Attributes      open                       high                          low  \
# Symbols         AAPL    GOOG     MSFT      AAPL      GOOG     MSFT      AAPL
# date
# 2015-01-02  103.8847  529.01  42.5088  103.9313  531.2700  43.2012  100.1169
# 2015-01-05  100.9936  523.26  42.2446  101.3293  524.3300  42.5725   98.3076
# 2015-01-06   99.3615  515.00  42.2537  100.1915  516.1750  42.5899   97.5802
# 2015-01-07   99.9770  507.00  41.8893  100.9096  507.2440  42.3266   99.5060
# 2015-01-08  101.8702  497.99  42.5908  104.5935  503.4800  43.5017  101.3759
# 2015-01-09  105.0784  504.76  43.3743  105.6194  504.9200  43.5656  102.7842
# 2015-01-12  105.0131  494.94  43.2012  105.0411  495.9760  43.3105  101.4692
# 2015-01-13  103.9220  498.84  42.7912  105.1997  502.9800  43.6476  101.5718
# 2015-01-14  101.6930  494.65  41.8710  103.0453  503.2300  42.1261  101.1894
# 2015-01-15  102.5883  505.57  42.1079  102.6443  505.6800  42.2537   99.4734
# ...

# %%
aapl_close = panel_data['close']['AAPL']

# %%
aapl_close
# Out:
# date
# 2015-01-02    101.9635
# 2015-01-05     99.0910
# 2015-01-06     99.1003
# 2015-01-07    100.4899
# 2015-01-08    104.3510
# 2015-01-09    104.4629
# 2015-01-12    101.8889
# 2015-01-13    102.7935
# 2015-01-14    102.4018
# 2015-01-15     99.6226
# 2015-01-16     98.8485
# 2015-01-20    101.3946
# 2015-01-21    102.1687
# 2015-01-22    104.8266
# 2015-01-23    105.3675
# 2015-01-26    105.4795
# 2015-01-27    101.7863
# 2015-01-28    107.5406
# 2015-01-29    110.8887
# 2015-01-30    109.2659
# 2015-02-02    110.6369
# 2015-02-03    110.6555
# 2015-02-04    111.5042
# 2015-02-05    112.3000
# 2015-02-06    111.3544
# 2015-02-09    112.0941
# 2015-02-10    114.2475
# 2015-02-11    116.9254
# 2015-02-12    118.4047
# 2015-02-13    118.9852
#                 ...
# 2016-11-17    106.6092
# 2016-11-18    106.7159
# 2016-11-21    108.3351
# 2016-11-22    108.4030
# 2016-11-23    107.8503
# 2016-11-25    108.3933
# 2016-11-28    108.1800
# 2016-11-29    108.0733
# ...

# %%
pickle_testing = pickle.load(open("pickle_testing", "rb"))

# %%
pickle_testing
# Out:
#                AMZN        SMA        upper        lower
# date
# 2017-04-24   907.41        NaN          NaN          NaN
# 2017-04-25   907.62        NaN          NaN          NaN
# 2017-04-26   909.29        NaN          NaN          NaN
# 2017-04-27   918.38        NaN          NaN          NaN
# 2017-04-28   924.99        NaN          NaN          NaN
# 2017-05-01   948.23        NaN          NaN          NaN
# 2017-05-02   946.94        NaN          NaN          NaN
# 2017-05-03   941.03        NaN          NaN          NaN
# 2017-05-04   937.53        NaN          NaN          NaN
# 2017-05-05   934.15        NaN          NaN          NaN
# 2017-05-08   949.04        NaN          NaN          NaN
# 2017-05-09   952.82        NaN          NaN          NaN
# 2017-05-10   948.95        NaN          NaN          NaN
# 2017-05-11   947.62        NaN          NaN          NaN
# 2017-05-12   961.35        NaN          NaN          NaN
# ...

# %%
pickle_testing.describe()
# Out:
#               AMZN          SMA        upper        lower
# count   251.000000   232.000000   232.000000   232.000000
# mean   1146.279482  1141.978211  1207.742578  1076.213844
# std     209.439445   199.577531   228.761601   174.281349
# min     907.410000   941.124000   978.056960   904.191040
# 25%     977.370000   981.938625  1017.898551   939.231962
# 50%    1026.870000  1015.461250  1115.880824   963.216285
# 75%    1316.255000  1279.815250  1416.331178  1147.199662
# max    1598.390000  1549.817000  1670.303919  1480.789736

# %%
pickle_testing.describe()["AMZN"]
# Out:
# count     251.000000
# mean     1146.279482
# std       209.439445
# min       907.410000
# 25%       977.370000
# 50%      1026.870000
# 75%      1316.255000
# max      1598.390000
# Name: AMZN, dtype: float64

# %%
type(pickle_testing.describe()["AMZN"])
# Out:
# pandas.core.series.Series

# %%
# TODO: convert from "binary on profitable" to "regression on change percent"

from keras.models import Model
from keras import Model
from keras_pandas import lib
from keras_pandas.Automater import Automater
from sklearn.model_selection import train_test_split
import pandas as pd
import stockstats as ss

#import util
import time
import argparse
import numpy as np
import matplotlib.pyplot as plt
from sys import argv,exit
from keras.models import Sequential
from keras.layers import Input, Dense,Dropout,GRU,Reshape
from keras.layers.normalization import BatchNormalization
import datetime

import numpy as np
import pandas as pd
from keras.models import Sequential  
from keras.layers.core import Dense, Activation  
from keras.layers.recurrent import LSTM
from sklearn.preprocessing import StandardScaler

import matplotlib.pyplot as plt
import winsound



def _load_data(data, n_prev=10):  
    """
    data should be pd.DataFrame()
    """
    docX, docY = [], []
    for i in range(len(data)-n_prev):
        docX.append(data.iloc[i:i+n_prev].as_matrix())
        docY.append(data.iloc[i+n_prev].as_matrix())
    alsX = np.array(docX)
    alsY = np.array(docY)
    return alsX, alsY

def time_series_split(df, test_size=0.2):  
    """
    This just splits data to training and testing parts
    """
    ntrn = round(len(df) * (1 - test_size))

    n_prex = 0
    X_train, y_train = _load_data(df.iloc[0:ntrn])
    X_test, y_test = _load_data(df.iloc[ntrn:])

    return (X_train, y_train), (X_test, y_test)

FEES = 0
def profitable(x):
    if x["change"] >= (0 + FEES):
        return 1
    elif x["change"] <= (0 - FEES):
        return 0

# %%
# Load data
#observations = lib.load_titanic()
btc = pd.read_csv("../Data/coinbase_minutely.csv") # loads data
btc = btc.iloc[::15, :].drop(['change'], axis=1) # slices every 15-min of data and removes now incorrect change
btc['change'] = btc['close'].pct_change().shift(-1) # recalculates change

#btc = pd.read_csv("../Data/SPY_in_theory_from_1-01-00_to_1-26-19.csv")
#print(btc.head())
btc = ss.StockDataFrame.retype(btc) #coerces df into StockDataFrame

#calculates and appends TA indicators to stock

btc['macd'] # calculate MACD indicator for the entire "btc" df and automatically appends to new column
btc['volume_delta']
btc['open_-1_r']
btc['cr']
btc['cr-ma1']
btc['cr-ma2']
btc['cr-ma3']
btc["rsi_6"]
btc["rsi_12"]
btc["wr_10"]
btc["cci"]
btc['tr']
btc['atr']
btc['dma']
btc['pdi']
btc['mdi']
btc['dx']
btc['adx']
btc['adxr']
btc['trix']
btc['trix_9_sma']
btc['vr']
btc.head()

#apply profitable function then clean dataset again
#btc["profitable"] = btc.apply(profitable, axis=1) #adding column "profitable" where +1 represents price went up and 0 represents price went down
#btc["profitable"] = btc["profitable"].shift(-1) #shifts "profitable" target column up 1 so current days stats predict tomorrow's profitability 

btc = btc[1:len(btc.index)-1] #removes first & last entry that now has NaN "profitable" column
btc = btc.dropna() #removes all rows containing any NaN values
print(len(btc))


btc = pd.DataFrame(btc)
change_list = btc['change'].values
#btc = btc.drop(["change"], axis=1).iloc[:,1:]
print(type(btc))
print(btc.head())

winsound.Beep(600,1200)
# Out:
# 63449
# <class 'pandas.core.frame.DataFrame'>
#      unnamed: 0   timestamp    open    high     low   close  volume    change  \
# 150        4284  1420690200  290.16  290.16  288.55  288.55    0.02 -0.003570
# 165        4299  1420691100  288.20  288.20  287.52  287.52    0.02  0.010747
# 180        4314  1420692000  299.38  299.38  290.61  290.61    0.03  0.014659
# 195        4329  1420692900  294.87  294.87  294.87  294.87    0.01  0.000950
# 210        4344  1420693800  285.33  295.15  285.33  295.15    0.02 -0.016331
#
#      close_26_ema      macd     ...            mdi      dx_14         dx  \
# 150    298.257366 -1.560968     ...      23.968625   1.274688   1.274688
# 165    296.938111 -1.873247     ...      23.645985   2.908609   2.908609
# 180    296.196774 -1.905444     ...      21.091443  14.759872  14.759872
# 195    296.047761 -1.657902     ...      19.644654  14.759872  14.759872
# 210    295.950646 -1.433450     ...      25.673893   3.970794   3.970794
#
#       dx_6_ema        adx  adx_6_ema       adxr      trix  trix_9_sma  \
# 150  10.414383  10.414383  20.139853  20.139853 -0.570834   -0.884077
# 165   8.215579   8.215579  16.646657  16.646657 -0.529586   -0.839352
# 180  10.118950  10.118950  14.748110  14.748110 -0.493245   -0.769944
# 195  11.461846  11.461846  13.797197  13.797197 -0.453235   -0.686492
# 210   9.302110   9.302110  12.501223  12.501223 -0.412105   -0.613547
#
#              vr
# 150   92.857143
# 165  107.142857
# 180  128.571429
# 195  135.714286
# 210  118.750000
#
# [5 rows x 57 columns]

# %%
#create train-test sets, then std'ize and check lengths

cval_split = 0.2
x_cval = btc.iloc[int(len(btc)*(1-cval_split)):, 8:].values
y_cval = btc.iloc[int(len(btc)*(1-cval_split)):, 7].values
x = btc.iloc[:int(len(btc)*(1-cval_split)), 8:].values
y = btc.iloc[:int(len(btc)*(1-cval_split)), 7].values

#btc = btc.drop(["change"], axis=1)
#x = btc.iloc[:, 8:].values
#y = btc.iloc[:, 7].values
#y = stock_month["profitable"]
#x = stock_month.drop(["profitable", "change"], axis=1) #move drop until after split to track data for backtesting

import random
RANDOM_STATE = 123
random.seed(RANDOM_STATE)
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = .3,random_state = RANDOM_STATE)
'''
training_split = 0.75
x_train = x[:int(len(x)*training_split)]
x_test = x[int(len(x)*training_split):]
y_train = y[:int(len(y)*training_split)]
y_test = y[int(len(y)*training_split):]
'''
sc = StandardScaler()
x_std_train = sc.fit_transform(x_train)
x_std_test = sc.transform(x_test)
#x_std_train = np.reshape(x_std_train, (x_std_train.shape[0], 1, x_std_train.shape[1])) #attempt to reshape for LSTM error, didn't work
#x_std_test = np.reshape(x_std_test, (x_std_test.shape[0], 1, x_std_test.shape[1])) #attempt to reshape for LSTM error, didn't work
#x_std_train = (x_train - x_train.mean())/x_train.std()
#x_std_test = (x_test - x_test.mean())/x_test.std()


#x_std_train = x_std_train.drop(["open","high","low","close","volume"], axis=1)
#x_std_test = x_std_test.drop(["open","high","low","close","volume"], axis=1)

print("X stuff")
print(x_std_train.shape)
print(x_std_test.shape)
print(x_train.shape[0]+x_test.shape[0])

print("Y stuff")
print(y_train.shape)
print(y_train.mean())
print(y_test.mean())
# Out:
# X stuff
# (35531, 49)
# (15228, 49)
# 50759
# Y stuff
# (35531,)
# 5.759381926182692e-05
# 2.0665139919560106e-06

# %%
print(y)
# Out:
# [-0.00356957  0.01074708  0.01465882 ...  0.00013807  0.00032787
#  -0.00134557]

# %%
# create model
model = Sequential()
model.add(Dense(12, input_dim=49, activation='tanh'))
model.add(Dense(24, activation='tanh'))
model.add(Dense(1, activation='tanh'))

# Compile model
model.compile(loss='mse', optimizer='adam', metrics=['mse'])

# Fit the model
model.fit(x_std_train, y_train, epochs=150, batch_size=32, validation_data=(x_test, y_test))

# evaluate the model
scores = model.evaluate(x_std_train, y_train)
print("\n%s: %.12f%%" % (model.metrics_names[1], scores[1]*100))

winsound.Beep(600,1200)
# Out:
# Train on 35531 samples, validate on 15228 samples
# Epoch 1/150
# 35531/35531 [==============================] - 4s 118us/step - loss: 0.0029 - mean_squared_error: 0.0029 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 2/150
# 35531/35531 [==============================] - 4s 125us/step - loss: 2.0414e-04 - mean_squared_error: 2.0414e-04 - val_loss: 3.5504e-04 - val_mean_squared_error: 3.5504e-04
# Epoch 3/150
# 35531/35531 [==============================] - 5s 128us/step - loss: 1.2706e-04 - mean_squared_error: 1.2706e-04 - val_loss: 2.2627e-04 - val_mean_squared_error: 2.2627e-04
# Epoch 4/150
# 35531/35531 [==============================] - 5s 136us/step - loss: 1.1159e-04 - mean_squared_error: 1.1159e-04 - val_loss: 2.5085e-04 - val_mean_squared_error: 2.5085e-04
# Epoch 5/150
# 35531/35531 [==============================] - 5s 131us/step - loss: 1.0334e-04 - mean_squared_error: 1.0334e-04 - val_loss: 3.9041e-04 - val_mean_squared_error: 3.9041e-04
# Epoch 6/150
# 35531/35531 [==============================] - 5s 131us/step - loss: 1.0256e-04 - mean_squared_error: 1.0256e-04 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 7/150
# 35531/35531 [==============================] - 5s 131us/step - loss: 9.5186e-05 - mean_squared_error: 9.5186e-05 - val_loss: 2.8278e-04 - val_mean_squared_error: 2.8278e-04
# Epoch 8/150
# 35531/35531 [==============================] - 5s 131us/step - loss: 8.1458e-05 - mean_squared_error: 8.1458e-05 - val_loss: 3.7766e-04 - val_mean_squared_error: 3.7766e-04
# Epoch 9/150
# 35531/35531 [==============================] - 5s 131us/step - loss: 8.3541e-05 - mean_squared_error: 8.3541e-05 - val_loss: 3.5299e-04 - val_mean_squared_error: 3.5299e-04
# Epoch 10/150
# 35531/35531 [==============================] - 5s 131us/step - loss: 7.3554e-05 - mean_squared_error: 7.3554e-05 - val_loss: 2.1855e-04 - val_mean_squared_error: 2.1855e-04
# Epoch 11/150
# 35531/35531 [==============================] - 5s 133us/step - loss: 7.8420e-05 - mean_squared_error: 7.8420e-05 - val_loss: 8.5871e-04 - val_mean_squared_error: 8.5871e-04
# Epoch 12/150
# 35531/35531 [==============================] - 5s 132us/step - loss: 7.1447e-05 - mean_squared_error: 7.1447e-05 - val_loss: 4.5819e-04 - val_mean_squared_error: 4.5819e-04
# Epoch 13/150
# 35531/35531 [==============================] - 5s 131us/step - loss: 7.9237e-05 - mean_squared_error: 7.9237e-05 - val_loss: 1.9116e-04 - val_mean_squared_error: 1.9116e-04
# Epoch 14/150
# 35531/35531 [==============================] - 5s 132us/step - loss: 6.6263e-05 - mean_squared_error: 6.6263e-05 - val_loss: 3.1981e-04 - val_mean_squared_error: 3.1981e-04
# Epoch 15/150
# 35531/35531 [==============================] - 5s 131us/step - loss:
# 35531/35531 [==============================] - 4s 104us/step - loss: 2.0649e-05 - mean_squared_error: 2.0649e-05 - val_loss: 9.3856e-04 - val_mean_squared_error: 9.3856e-04
# Epoch 150/150
# 35531/35531 [==============================] - 3s 91us/step - loss: 2.4194e-05 - mean_squared_error: 2.4194e-05 - val_loss: 0.0014 - val_mean_squared_error: 0.0014
# 35531/35531 [==============================] - 1s 35us/step
#
# mean_squared_error: 0.00%

# %%
print(model.metrics_names)
print("\n%s: %.12f%%" % (model.metrics_names[1], scores[1]))
# Out:
# ['loss', 'mean_squared_error']
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-c1bd0287aae4> in <module>
#       1 print(model.metrics_names)
# ----> 2 print("\n%s: %.12f%" % (model.metrics_names[1], scores[1]))
#
# ValueError: incomplete format

# %%
# TODO: figure out why this always predicts the same values of -0.0021221174 ?????
### TODO: what happens if you switch "validation_data=(x_test, y_test)" to cval data then use "x_test & y_test" for predictions???

y_pred = model.predict(x_cval)
print(y_pred)

clean_y_pred = []
for val1 in y_pred:
    for val2 in val1:
        #print(val2)
        clean_y_pred.append(val2)
        
print(clean_y_pred)
print(y_test)

answers_df = pd.DataFrame(
    {#'close': close,
     'change': y_cval, # convert to changes for x_test only
     'predictions': clean_y_pred
    })

answers_df.to_excel("../Data/answers_keras_btc2.xlsx")
# Out:
# [[-0.00212212]
#  [-0.00212212]
#  [-0.00212212]
#  ...
#  [-0.00212212]
#  [-0.00212212]
#  [-0.00212212]]
# [-0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, 0.07530804, -0.0021212234, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.0021221174, -0.002122117 ...
# [-0.00226432 -0.00100175  0.00034469 ... -0.00095884 -0.00015675
#  -0.00069467]

# %%
y_pred = model.predict(x_std_test)
print(y_pred)

clean_y_pred = []
for val1 in y_pred:
    for val2 in val1:
        #print(val2)
        clean_y_pred.append(val2)
        
print(clean_y_pred)
print(y_test)

answers_df = pd.DataFrame(
    {#'close': close,
     'change': y_test, # convert to changes for x_test only
     'predictions': clean_y_pred
    })

answers_df.to_excel("../Data/answers_keras_btc.xlsx")
# Out:
# [[ 0.00715831]
#  [-0.00508043]
#  [-0.03899516]
#  ...
#  [-0.00546538]
#  [-0.00385934]
#  [-0.00816025]]
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
print(x_std_test)
# Out:
# [[-0.046318    0.21768869  0.1788439  ... -0.79185132  0.16684141
#    0.13907777]
#  [-0.03597296 -0.04507645 -0.01055074 ...  0.80154448 -0.03037266
#    0.0086371 ]
#  [-0.05263817  0.15788327  0.16579809 ... -0.702218    0.1254768
#    0.11663272]
#  ...
#  [-0.88766188  0.03692758  0.03072523 ...  0.3387373   0.09032996
#    0.0833828 ]
#  [-0.79179994 -0.6714531  -0.55574744 ...  2.33610392 -0.71421487
#   -0.60362167]
#  [-1.08555676 -0.8462395  -0.74375401 ... -1.01808666 -1.36991947
#   -0.97292207]]

# %%
def beeper(freq = 600, duration = 1000):
    winsound.Beep(freq, duration)

# %%
from keras import backend as K
K.tensorflow_backend._get_available_gpus()
import tensorflow as tf
print(tf.test.is_built_with_cuda())
# Out:
# False
